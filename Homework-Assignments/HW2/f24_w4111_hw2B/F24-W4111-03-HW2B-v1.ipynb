# %% [markdown]
# # F24-W4111-03: Introduction to Databases: Homework 2, Part B

# %% [markdown]
# Nathan Gong

# %% [markdown]
# ## Submission Instructions

# %% [markdown]
# __Note to TAs:__ The TAs will post submission instructions on Ed, CourseWorks and GradeScope.

# %% [markdown]
# ## Environment Setup

# %% [markdown]
# ### Check Packages and Connections

# %% [markdown]
# This section tests your environment for HW1B.
#
# If you successfuly completed HW0, you should not have any problems.
#
# Please make sure you set your MySQL user id and password correctly.

# %%
# %pip install pandas
import pandas

# %%
import sqlalchemy

# %%
import pymysql

# %%
import json

# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:dbuserdbuser@localhost

# %%
engine = sqlalchemy.create_engine("mysql+pymysql://root:dbuserdbuser@localhost")

# %% [markdown]
# ### Sample Database

# %% [markdown]
# For this homework, we need a more complex database and sample data to adequately write and test complex SQL.
#
# We will use the [Classic Models example database](https://www.mysqltutorial.org/getting-started-with-mysql/mysql-sample-database/) for this homework and subsequent homework assignments. The SQL script for creating the database/schema and loading the data is in the same GitHub directory as this notebook. If you downloaded a zip file to start HW2B, the file is in the directory containing the notebook.

# %%
# %ls -l *.sql
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 940C-3CFD
#
#  Directory of C:\Users\natha\W4111-Intro-to-Databases-Base\Homework-Assignments\HW2\f24_w4111_hw2B
#
#
#  Directory of C:\Users\natha\W4111-Intro-to-Databases-Base\Homework-Assignments\HW2\f24_w4111_hw2B
#
# 10/10/2024  03:00 PM           195,764 mysqlsampledatabase.sql
#                1 File(s)        195,764 bytes
#                0 Dir(s)  805,904,437,248 bytes free

# %% [markdown]
# You install and create the database and install the code in the same way you set up and installed the sample database associated with the recommended textbook. You performed this task earlier in the semester. The [steps](https://www.mysqltutorial.org/getting-started-with-mysql/how-to-load-sample-database-into-mysql-database-server/) for installing the database using the command line is also on the website for Classic Models.

# %% [markdown]
# The following cell will check if you have correctly installed the database.

# %%
# %%sql
#
# use classicmodels;
#
# with one as (
#     select
#         *
#     from
#         orders join orderdetails using(orderNumber)
# ),
#     two as (
#         select
#             *
#         from
#             customers join one using(customerNumber)
#     ),
#     three as (
#         select
#             *
#         from
#             two join products using(productCode)
#     )
# select
#     customerNumber,
#     customerName,
#     orderNumber,
#     status,
#     quantityOrdered,
#     priceEach,
#     orderLineNumber,
#     productName,
#     productVendor
# from
#     three
# where
#     customerNumber = 114
# order by
#     customerNumber, orderNumber, orderLineNumber;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 55 rows affected.
# [(114, 'Australian Collectors, Co.', 10120, 'Shipped', 35, Decimal('110.45'), 1, '1997 BMW R 1100 S', 'Autoart Studio Design'),
#  (114, 'Australian Collectors, Co.', 10120, 'Shipped', 46, Decimal('158.80'), 2, '2003 Harley-Davidson Eagle Drag Bike', 'Red Start Diecast'),
#  (114, 'Australian Collectors, Co.', 10120, 'Shipped', 29, Decimal('118.94'), 3, '1996 Moto Guzzi 1100i', 'Highway 66 Mini Classics'),
#  (114, 'Australian Collectors, Co.', 10120, 'Shipped', 46, Decimal('57.54'), 4, '1936 Harley Davidson El Knucklehead', 'Welly Diecast Productions'),
#  (114, 'Australian Collectors, Co.', 10120, 'Shipped', 34, Decimal('72.36'), 5, '1960 BSA Gold Star DBD34', 'Highway 66 Mini Classics'),
#  (114, 'Australian Collectors, Co.', 10120, 'Shipped', 22, Decimal('94.90'), 6, '1997 BMW F650 ST', 'Exoto Designs'),
#  (114, 'Australian Collectors, Co.', 10120, 'Shipped', 24, Decimal('106.79'), 7, 'ATA: B757-300', 'Highway 66 Mini Classics'),
#  (114, 'Australian Collectors, Co.', 10120, 'Shipped', 29, Decimal('82.79'), 8, 'P-51-D Mustang', 'Gearbox Collectibles'),
#  (114, 'Australian Collectors, Co.', 10120, 'Shipped', 29, Decimal('71.73'), 9, '1900s Vintage Tri-Plane', 'Unimax Art Galleries'),
#  (114, 'Australian Collectors, Co.', 10120, 'Shipped', 39, Decimal('93.01'), 10, '1928 British Royal Navy Airplane', 'Classic Metal Creations'),
#  (114, 'Australian Collectors, Co.', 10120, 'Shipped', 29, Decimal('68.79'), 11, '1928 Ford Phaeton Deluxe', 'Highway 66 Mini Classics'),
#  (114, 'Australian Collectors, Co.', 10120, 'Shipped', 49, Decimal('41.46'), 12, '1930 Buick Marquette Phaeton', 'Studio M Art Models'),
#  (114, 'Australian Collectors, Co.', 10120, 'Shipped', 47, Decimal('91.34'), 13, 'American Airlines: B767-300', 'Min Lin Diecast'),
#  (114, 'Australian Collectors, Co.', 10120, 'Shipped', 43, Decimal('72.00'), 14, 'F/A 18 Hornet 1/72', 'Motor City Art Classics'),
#  (114, 'Australian Collectors, Co.', 10120, 'Shipped', 24, Decimal('81.77'), 15, 'America West Airlines B757-200', 'Motor City Art Classics'),
#  (114, 'Australian Collectors, Co.', 10125, 'Shipped', 32, Decimal('89.38'), 1, '1937 Lincoln Berline', 'Motor City Art Classics'),
#  (114, 'Australian Collectors, Co.', 10125, 'Shipped', 34, Decimal('138.38'), 2, '1928 Mercedes-Benz SSK', 'Gearbox Collectibles'),
#  (114, 'Australian Collectors, Co.', 10223, 'Shipped', 37, Decimal('80.39'), 1, '1969 Harley Davidson Ultimate Chopper', 'Min Lin Diecast'),
#  (114, 'Australian Collectors, Co.', 10223, 'Shipped', 32, Decimal('104.81'), 2, '1997 BMW R 1100 S', 'Autoart Studio Design'),
#  (114, 'Australian Collectors, Co.', 10223, 'Shipped', 49, Decimal('189.79'), 3, '2003 Harley-Davidson Eagle Drag Bike', 'Red Start Diecast'),
#  (114, 'Australian Collectors, Co.', 10223, 'Shipped', 47, Decimal('110.61'), 4, '1996 Moto Guzzi 1100i', 'Highway 66 Mini Classics'),
#  (114, 'Australian Collectors, Co.', 10223, 'Shipped', 28, Decimal('58.75'), 5, '1936 Harley Davidson El Knucklehead', 'Welly Diecast Productions'),
#  (114, 'Australian Collectors, Co.', 10223, 'Shipped', 38, Decimal('60.94'), 6, '1960 BSA Gold Star DBD34', 'Highway 66 Mini Classics'),
#  (114, 'Australian Collectors, Co.', 10223, 'Shipped', 21, Decimal('90.90'), 7, '1997 BMW F650 ST', 'Exoto Designs'),
#  (114, 'Australian Collectors, Co.', 10223, 'Shipped', 29, Decimal('113.90'), 8, 'ATA: B757-300', 'Highway 66 Mini Classics'),
#  (114, 'Australian Collectors, Co.', 10223, 'Shipped', 47, Decimal('67.58'), 9, 'P-51-D Mustang', 'Gearbox Collectibles'),
#  (114, 'Australian Collectors, Co.', 10223, 'Shipped', 23, Decimal('68.10'), 10, '1900s Vintage Tri-Plane', 'Unimax Art Galleries'),
#  (114, 'Australian Collectors, Co.', 10223, 'Shipped', 34, Decimal('87.54'), 11, '1928 British Royal Navy Airplane', 'Classic Metal Creations'),
#  (114, 'Australian Collectors, Co.', 10223, 'Shipped', 20, Decimal('66.73'), 12, '1928 Ford Phaeton Deluxe', 'Highway 66 Mini Classics'),
#  (114, 'Australian Collectors, Co.', 10223, 'Shipped', 41, Decimal('41.02'), 13, '1930 Buick Marquette Phaeton', 'Studio M Art Models'),
#  (114, 'Australian Collectors, Co.', 10223, 'Shipped', 25, Decimal('84.03'), 14, 'American Airlines: B767-300', 'Min Lin Diecast'),
#  (114, 'Australian Collectors, Co.', 10223, 'Shipped', 26, Decimal('79.20'), 15, 'F/A 18 Hornet 1/72', 'Motor City Art Classics'),
#  (114, 'Australian Collectors, Co.', 10342, 'Shipped', 55, Decimal('63.14'), 1, '1948 Porsche 356-A Roadster', 'Gearbox Collectibles'),
#  (114, 'Australian Collectors, Co.', 10342, 'Shipped', 40, Decimal('118.89'), 2, '1993 Mazda RX-7', 'Highway 66 Mini Classics'),
#  (114, 'Australian Collectors, Co.', 10342, 'Shipped', 22, Decimal('115.22'), 3, '1995 Honda Civic', 'Min Lin Diecast'),
#  (114, 'Australian Collectors, Co.', 10342, 'Shipped', 30, Decimal('167.65'), 4, '1992 Ferrari 360 Spider red', 'Unimax Art Galleries'),
#  (114, 'Australian Collectors, Co.', 10342, 'Shipped', 25, Decimal('76.39'), 5, '1969 Dodge Super Bee', 'Min Lin Diecast'),
#  (114, 'Australian Collectors, Co.', 10342, 'Shipped', 42, Decimal('112.34'), 6, '1956 Porsche 356A Coupe', 'Classic Metal Creations'),
#  (114, 'Australian Collectors, Co.', 10342, 'Shipped', 55, Decimal('136.70'), 7, '1976 Ford Gran Torino', 'Gearbox Collectibles'),
#  (114, 'Australian Collectors, Co.', 10342, 'Shipped', 26, Decimal('57.82'), 8, '1957 Vespa GS150', 'Studio M Art Models'),
#  (114, 'Australian Collectors, Co.', 10342, 'Shipped', 39, Decimal('30.59'), 9, '1982 Lamborghini Diablo', 'Second Gear Diecast'),
#  (114, 'Australian Collectors, Co.', 10342, 'Shipped', 48, Decimal('60.01'), 10, '1971 Alpine Renault 1600s', 'Welly Diecast Productions'),
#  (114, 'Australian Collectors, Co.', 10342, 'Shipped', 38, Decimal('124.99'), 11, '1957 Corvette Convertible', 'Classic Metal Creations'),
#  (114, 'Australian Collectors, Co.', 10347, 'Shipped', 30, Decimal('188.58'), 1, '1952 Alpine Renault 1300', 'Classic Metal Creations'),
#  (114, 'Australian Collectors, Co.', 10347, 'Shipped', 27, Decimal('132.97'), 2, '1962 LanciaA Delta 16V', 'Second Gear Diecast'),
#  (114, 'Australian Collectors, Co.', 10347, 'Shipped', 29, Decimal('132.57'), 3, '1958 Setra Bus', 'Welly Diecast Productions'),
#  (114, 'Australian Collectors, Co.', 10347, 'Shipped', 45, Decimal('115.03'), 4, '1940s Ford truck', 'Motor City Art Classics'),
#  (114, 'Australian Collectors, Co.', 10347, 'Shipped', 42, Decimal('113.17'), 5, '1940 Ford Pickup Truck', 'Studio M Art Models'),
#  (114, 'Australian Collectors, Co.', 10347, 'Shipped', 21, Decimal('136.69'), 6, '1928 Mercedes-Benz SSK', 'Gearbox Collectibles'),
#  (114, 'Australian Collectors, Co.', 10347, 'Shipped', 21, Decimal('46.36'), 7, '1936 Mercedes-Benz 500K Special Roadster', 'Studio M Art Models'),
#  (114, 'Australian Collectors, Co.', 10347, 'Shipped', 50, Decimal('51.05'), 8, '1926 Ford Fire Engine', 'Carousel DieCast Legends'),
#  (114, 'Australian Collectors, Co.', 10347, 'Shipped', 48, Decimal('84.09'), 9, '1913 Ford Model T Speedster', 'Carousel DieCast Legends'),
#  (114, 'Australian Collectors, Co.', 10347, 'Shipped', 34, Decimal('60.59'), 10, '1934 Ford V8 Coupe', 'Min Lin Diecast'),
#  (114, 'Australian Collectors, Co.', 10347, 'Shipped', 45, Decimal('95.30'), 11, '18th Century Vintage Horse Carriage', 'Red Start Diecast'),
#  (114, 'Australian Collectors, Co.', 10347, 'Shipped', 26, Decimal('84.33'), 12, '1917 Maxwell Touring Car', 'Exoto Designs')]

# %% [markdown]
# ## Entity Relationship Modeling

# %% [markdown]
# ### Create Entity Relationship Model

# %% [markdown]
# The ability to take a high-level description of a required database and produce an ER-diagram is one of the most fundamental skills needed for using databases. Consider the following scenario for creating a data model for the Harry Potter series of books.
#
# The data model has the following entity types:
# 1. ```Character``` has the properties:
#     - ```last_name```
#     - ```first_name```
#     - ```description```
# 2. ```Book``` has the properties:
#     - ```title```
#     - ```volume_number``` is the ordinal number of the book in the overall series. For example, [Harry Potter and the Goblet of Fire](https://reedsy.com/discovery/blog/harry-potter-books-in-order) has ```volume_number``` 4.
#     - ```publication_year```
# 3. ```Chapter``` has the properties:
#     - ```volume_number```
#     - ```chapter_number```
#     - ```chapter_title```
#     - ```chapter_summary```
# 4. ```Event``` has the following properties:
#     - ```event_type``` is a value from a list of possible event types. The data model should support adding new allowed values for ```event_type``` without requiring changing the data model/schema.
#     - ```event_description```

# %% [markdown]
# This is where things get tricky. People think of an ```Event``` having a form like:
#
#
# 1. Event: Harry Receives His Hogwarts Letter
# - **Type:** Milestone
# - **Description:** After multiple failed attempts to deliver a letter to Harry, Hagrid personally delivers his acceptance letter to Hogwarts.
# - **Participants:** Harry Potter, Hagrid, Dursley Family
# - **Book:** *Harry Potter and the Philosopher's Stone*
# - **Chapter:** Chapter 4: "The Keeper of the Keys"
#
# 2. Event: Sorting Hat Ceremony
# - **Type:** Ceremony
# - **Description:** Harry and his classmates are sorted into their respective houses. Harry is placed in Gryffindor despite the Sorting Hat considering Slytherin.
# - **Participants:** Harry Potter, Ron Weasley, Hermione Granger, Draco Malfoy, Sorting Hat
# - **Book:** *Harry Potter and the Philosopher's Stone*
# - **Chapter:** Chapter 7: "The Sorting Hat"
#
# 3. Event: Battle of the Department of Mysteries
# - **Type:** Battle
# - **Description:** Harry and his friends fight Death Eaters at the Ministry of Magic. Sirius Black is killed by Bellatrix Lestrange.
# - **Participants:** Harry Potter, Hermione Granger, Ron Weasley, Neville Longbottom, Luna Lovegood, Ginny Weasley, Death Eaters, Order of the Phoenix
# - **Book:** *Harry Potter and the Order of the Phoenix*
# - **Chapter:** Chapter 35: "Beyond the Veil"
#
# 4. Event: Dumbledore's Death
# - **Type:** Tragedy
# - **Description:** Severus Snape kills Albus Dumbledore at the top of the Astronomy Tower, as part of a prearranged plan.
# - **Participants:** Albus Dumbledore, Severus Snape, Draco Malfoy, Death Eaters
# - **Book:** *Harry Potter and the Half-Blood Prince*
# - **Chapter:** Chapter 27: "The Lightning-Struck Tower"
#
# 5. Event: Harry's Final Duel with Voldemort
# - **Type:** Battle
# - **Description:** Harry confronts Voldemort in the Great Hall and finally defeats him, bringing an end to the Dark Lord's reign.
# - **Participants:** Harry Potter, Lord Voldemort
# - **Book:** *Harry Potter and the Deathly Hallows*
# - **Chapter:** Chapter 36: "The Flaw in the Plan"

# %% [markdown]
# You must define and diagram an ER model using Crow's Foot notation that enables representing the information in a relational/SQL database. This should include defining:
# - Primary keys
# - Foreign keys
# - Relationships necessary to represent and store the data.
#
# To accomplish the task, you _may_ need to create additional entity types, attributes, etc.
#
# In the cell below, please document any assumptions/design decisions you make and include the ER diagram.

# %% [markdown]
# __Answer:__
#
# Assumptions/design decisions:
# * ```Character``` has a unique identifier ```character_id``` which acts as its primary key
# * ```Character``` has a foreign key ```volume_number``` which refers to ```Book.volume_number```, and a ```Character``` may belong to 1 or many ```Book```s
# * A ```Character``` may belong to 0 or many ```Event```s
# * ```Book``` has a unique identifier ```volume_number``` which acts as its primary key. ```title``` is also a unique key (normally book titles are not guaranteed to be unique, but all the books in the Harry Potter series have unique titles)
# * A ```Book``` may have 0 or many ```Character```s
# * A ```Book``` may have 0 or many ```Chapter```s
# * ```Chapter``` has a unique identifier ```chapter_id``` which acts as its primary key
# * ```Chapter``` has a foreign key ```volume_number``` which refers to ```Book.volume_number```, and a ```Chapter``` may belong to only 1 ```Book```
# * A ```Chapter``` may have 0 or many ```Event```s
# * ```Event``` has a unique identifier ```event_id``` which acts as its primary key
# * ```Event``` has a foreign key ```character_id``` which refers to ```Character.character```, and an ```Event``` may have 0 or many ```Character```s
# * ```Event``` has a foreign key ```chapter_id``` which refers to ```Chapter.chapter_id```, and an ```Event``` may belong to only 1 ```Chapter```
# * The ```EventType``` entity type allows for adding new allowed values for types of ```Event```s without requiring changing the data model.
# * ```EventType``` has a unique identifier ```event_type_id``` which acts as its primary key
# * ```Event``` has a foreign key ```event_type_id``` which refers to ```EventType.event_type_id```, and an ```Event``` may have only 1 ```EventType```
# * The ```Event``` form can be generated from its attributes and from its direct and indirect relationships with ```EventType```, ```Character```, ```Book```, and ```Chapter```
#
#
# ER Diagram
#
# <img src="./harrypotter.jpeg">

# %% [markdown]
# ### Implement ER Diagram

# %% [markdown]
# The diagram below is a simple ER Model using specialization to model companies with which a corporation may do business. You must create a database with the name ```w4111_hw2_<uni>```, replacing ```<uni>``` with your UNI.
#
# Your implementation must use the _3 Table Solution_ to modeling specialization.
#
# You need to create the necessary primary keys, foreign keys, views, etc. A query on the table/view ```Company``` must include a column indicating whether the ```Company``` is a ```Supplier``` or a ```Customer.```

# %% [markdown]
# | <img src="./er_to_sql_data_model.jpg"> |
# | :---: |
# | ER to SQL Data Model |

# %%
# %%sql
#
# /* Your create and alter table statements. */
#
# CREATE DATABASE IF NOT EXISTS w4111_hw2_ng2695;
# USE w4111_hw2_ng2695;
#
# CREATE TABLE IF NOT EXISTS Company_t (
#     ID CHAR(12),
#     name VARCHAR(64),
#     created_timestamp TIMESTAMP DEFAULT CURRENT_TIMESTAMP NOT NULL,
#     type CHAR(1),
#     PRIMARY KEY (ID)
# );
#
# CREATE TRIGGER before_company_t_update
# BEFORE UPDATE on Company_t
# FOR EACH ROW
# BEGIN
#     IF New.created_timestamp <> OLD.created_timestamp THEN
#         SIGNAL SQLSTATE '45000'
#         SET MESSAGE_TEXT = 'Error: Cannot change the value of the created_timestamp field';
#     END IF;
# END;
#
# CREATE TABLE IF NOT EXISTS Supplier_t (
#     ID CHAR(12),
#     rating TINYINT,
#     product_name VARCHAR(64),
#     CHECK (rating IN (0, 1, 2, 3, 4, 5)),
#     PRIMARY KEY (ID),
#     FOREIGN KEY (ID) REFERENCES Company_t(ID)
# );
#
# CREATE TABLE IF NOT EXISTS Customer_t (
#     ID CHAR(12),
#     credit_limit INT,
#     credit_rating ENUM('Excellent', 'Good', 'Fair', 'Poor', 'Terrible') NOT NULL,
#     PRIMARY KEY (ID),
#     FOREIGN KEY (ID) REFERENCES Company_t(ID)
# );
#
# DROP VIEW IF EXISTS Company;
# CREATE VIEW Company AS
# SELECT
#     c.ID AS ID,
#     c.name AS name,
#     c.created_timestamp AS created_timestamp,
#     c.type AS type,
#     s.rating AS rating,
#     s.product_name AS product_name,
#     c2.credit_limit AS credit_limit,
#     c2.credit_rating AS credit_rating
# FROM
#     Company_t AS c
# LEFT JOIN
#     Supplier_t AS s ON c.ID = s.ID
# LEFT JOIN
#     Customer_t AS c2 ON c.ID = c2.ID;
#
# DROP VIEW IF EXISTS Supplier;
# CREATE VIEW Supplier AS
# SELECT
#     c.ID AS ID,
#     c.name AS name,
#     c.created_timestamp AS created_timestamp,
#     s.rating AS rating,
#     s.product_name AS product_name
# FROM
#     Company_t AS c
# LEFT JOIN
#     Supplier_t AS s ON c.ID = s.ID;
#
# DROP VIEW IF EXISTS Customer;
# CREATE VIEW Customer AS
# SELECT
#     c.ID AS ID,
#     c.name AS name,
#     c.created_timestamp AS created_timestamp,
#     c2.credit_limit AS credit_limit,
#     c2.credit_rating AS credit_rating
# FROM
#     Company_t AS c
# LEFT JOIN
#     Customer_t AS c2 ON c.ID = c2.ID;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ## Relational Algebra

# %% [markdown]
# You will use the Relax calulator and the schema associated with the text book for this question.
#
# https://dbis-uibk.github.io/relax/calc/gist/4f7866c17624ca9dfa85ed2482078be8/relax-silberschatz-english.txt/0

# %% [markdown]
# Write a relational algebra expression that produces a relation of the form
#
# ```(student_id, student_name, student_dept, advisor_id, advisor_name, advisor_dept)```
#
# All students must have a row in the result, event if the student does not have an advisor. All instructors must appear in the result even if the instructor does not advise an students.
#
# Follow the format you used for the previous homework, i.e. paste the text of your expression in the markdown cell below and include the execution result for your expression. You only need to include the first page of results if there is more than one page of results.

# %% [markdown]
# <hr>
# Text copy of your relational algebra expression.
#
# <hr>

# %% [markdown]
# π student.ID->student_id, student.name->student_name, student.dept_name->student_dept, advisor.i_id->advisor_id, instructor.name->advisor_name, instructor.dept_name->advisor_dept (instructor ⟗ instructor.ID=advisor.i_id (student ⟕ student.ID=advisor.s_id advisor))

# %% [markdown]
# <hr>
# Execute your query on the Relax calculator and show an image of the first page of your result below.
# <hr>

# %% [markdown]
# <img src="./relax.png">

# %% [markdown]
# ## SQL

# %% [markdown]
# Use the Classic Models database for these questions.

# %% [markdown]
# Write a SQL statement that produces a table of the form
#
# ```(country, productCode, productName, no_of_customers, number_of_orders)```
#
# Where
# - ```country``` is the ```country``` from the ```customers``` table.
# - ```product_code``` and ```product_name``` has the obvious meaning.
# - ```no_of_customers``` is the distinct number of customers that ordered the product.
# - ```number_of_orders``` is the number of orders that contained an ```orderdetails``` with the ```product_code.```
#
# The result should show 0 for ```number_of_customers``` and ```number_of_orders``` when there have been no orders for a product by a customer in the country.

# %%
# %%sql
#
# USE classicmodels;
#
# SELECT
#     c.country AS country,
#     p.productCode AS productCode,
#     p.productName AS productName,
#     COUNT(DISTINCT c.customerNumber) AS no_of_customers,
#     COUNT(od.orderNumber) AS number_of_orders
# FROM
#     products p
# LEFT JOIN
#     orderdetails od ON p.productCode = od.productCode
# LEFT JOIN
#     orders o ON od.orderNumber = o.orderNumber
# LEFT JOIN
#     customers c ON o.customerNumber = c.customerNumber
# GROUP BY
#     c.country, p.productCode, p.productName
# ORDER BY
#     c.country, p.productCode;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 1217 rows affected.
# [(None, 'S18_3233', '1985 Toyota Supra', 0, 0),
#  ('Australia', 'S10_1678', '1969 Harley Davidson Ultimate Chopper', 2, 2),
#  ('Australia', 'S10_1949', '1952 Alpine Renault 1300', 4, 4),
#  ('Australia', 'S10_2016', '1996 Moto Guzzi 1100i', 3, 4),
#  ('Australia', 'S10_4698', '2003 Harley-Davidson Eagle Drag Bike', 2, 3),
#  ('Australia', 'S10_4962', '1962 LanciaA Delta 16V', 3, 4),
#  ('Australia', 'S12_1099', '1968 Ford Mustang', 1, 1),
#  ('Australia', 'S12_1666', '1958 Setra Bus', 4, 5),
#  ('Australia', 'S12_2823', '2002 Suzuki XREO', 1, 1),
#  ('Australia', 'S12_3990', '1970 Plymouth Hemi Cuda', 1, 1),
#  ('Australia', 'S18_1097', '1940 Ford Pickup Truck', 4, 5),
#  ('Australia', 'S18_1129', '1993 Mazda RX-7', 2, 2),
#  ('Australia', 'S18_1342', '1937 Lincoln Berline', 4, 4),
#  ('Australia', 'S18_1367', '1936 Mercedes-Benz 500K Special Roadster', 4, 4),
#  ('Australia', 'S18_1589', '1965 Aston Martin DB5', 1, 1),
#  ('Australia', 'S18_1749', '1917 Grand Touring Sedan', 2, 2),
#  ('Australia', 'S18_1889', '1948 Porsche 356-A Roadster', 1, 1),
#  ('Australia', 'S18_1984', '1995 Honda Civic', 2, 2),
#  ('Australia', 'S18_2248', '1911 Ford Town Car', 2, 2),
#  ('Australia', 'S18_2319', '1964 Mercedes Tour Bus', 1, 1),
#  ('Australia', 'S18_2325', '1932 Model A Ford J-Coupe', 2, 2),
#  ('Australia', 'S18_2432', '1926 Ford Fire Engine', 2, 3),
#  ('Australia', 'S18_2581', 'P-51-D Mustang', 2, 3),
#  ('Australia', 'S18_2625', '1936 Harley Davidson El Knucklehead', 2, 3),
#  ('Australia', 'S18_2795', '1928 Mercedes-Benz SSK', 3, 4),
#  ('Australia', 'S18_2870', '1999 Indy 500 Monte Carlo SS', 1, 1),
#  ('Australia', 'S18_2949', '1913 Ford Model T Speedster', 5, 6),
#  ('Australia', 'S18_2957', '1934 Ford V8 Coupe', 3, 3),
#  ('Australia', 'S18_3136', '18th Century Vintage Horse Carriage', 3, 4),
#  ('Australia', 'S18_3232', '1992 Ferrari 360 Spider red', 2, 3),
#  ('Australia', 'S18_3278', '1969 Dodge Super Bee', 3, 3),
#  ('Australia', 'S18_3320', '1917 Maxwell Touring Car', 3, 3),
#  ('Australia', 'S18_3482', '1976 Ford Gran Torino', 3, 3),
#  ('Australia', 'S18_3685', '1948 Porsche Type 356 Roadster', 1, 1),
#  ('Australia', 'S18_3782', '1957 Vespa GS150', 2, 2),
#  ('Australia', 'S18_3856', '1941 Chevrolet Special Deluxe Cabriolet', 1, 1),
#  ('Australia', 'S18_4027', '1970 Triumph Spitfire', 1, 1),
#  ('Australia', 'S18_4409', '1932 Alfa Romeo 8C2300 Spider Sport', 3, 3),
#  ('Australia', 'S18_4600', '1940s Ford truck', 3, 3),
#  ('Australia', 'S18_4668', '1939 Cadillac Limousine', 3, 3),
#  ('Australia', 'S18_4721', '1957 Corvette Convertible', 2, 2),
#  ('Australia', 'S18_4933', '1957 Ford Thunderbird', 3, 3),
#  ('Australia', 'S24_1046', '1970 Chevy Chevelle SS 454', 2, 2),
#  ('Australia', 'S24_1444', '1970 Dodge Coronet', 1, 1),
#  ('Australia', 'S24_1578', '1997 BMW R 1100 S', 2, 3),
#  ('Australia', 'S24_1628', '1966 Shelby Cobra 427 S/C', 2, 2),
#  ('Australia', 'S24_1785', '1928 British Royal Navy Airplane', 2, 3),
#  ('Australia', 'S24_1937', '1939 Chevrolet Deluxe Coupe', 3, 3),
#  ('Australia', 'S24_2000', '1960 BSA Gold Star DBD34', 1, 2),
#  ('Australia', 'S24_2022', '1938 Cadillac V-16 Presidential Limousine', 2, 2),
#  ('Australia', 'S24_2360', '1982 Ducati 900 Monster', 1, 1),
#  ('Australia', 'S24_2766', '1949 Jaguar XK 120', 2, 2),
#  ('Australia', 'S24_2841', '1900s Vintage Bi-Plane', 1, 1),
#  ('Australia', 'S24_2887', '1952 Citroen-15CV', 2, 2),
#  ('Australia', 'S24_2972', '1982 Lamborghini Diablo', 1, 1),
#  ('Australia', 'S24_3191', '1969 Chevrolet Camaro Z28', 2, 2),
#  ('Australia', 'S24_3371', '1971 Alpine Renault 1600s', 2, 2),
#  ('Australia', 'S24_3420', '1937 Horch 930V Limousine', 2, 2),
#  ('Australia', 'S24_3432', '2002 Chevy Corvette', 2, 2),
#  ('Australia', 'S24_3856', '1956 Porsche 356A Coupe', 1, 1),
#  ('Australia', 'S24_3949', 'Corsair F4U ( Bird Cage)', 1, 1),
#  ('Australia', 'S24_3969', '1936 Mercedes Benz 500k Roadster', 2, 2),
#  ('Australia', 'S24_4048', '1992 Porsche Cayenne Turbo Silver', 1, 1),
#  ('Australia', 'S24_4258', '1936 Chrysler Airflow', 2, 2),
#  ('Australia', 'S24_4278', '1900s Vintage Tri-Plane', 2, 3),
#  ('Australia', 'S24_4620', '1961 Chevrolet Impala', 1, 1),
#  ('Australia', 'S32_1268', '1980ÔÇÖs GM Manhattan Express', 1, 1),
#  ('Australia', 'S32_1374', '1997 BMW F650 ST', 1, 2),
#  ('Australia', 'S32_2206', '1982 Ducati 996 R', 1, 1),
#  ('Australia', 'S32_3207', "1950's Chicago Surface Lines Streetcar", 1, 1),
#  ('Australia', 'S32_3522', '1996 Peterbilt 379 Stake Bed with Outrigger', 2, 2),
#  ('Australia', 'S32_4289', '1928 Ford Phaeton Deluxe', 2, 3),
#  ('Australia', 'S32_4485', '1974 Ducati 350 Mk3 Desmo', 1, 1),
#  ('Australia', 'S50_1341', '1930 Buick Marquette Phaeton', 2, 3),
#  ('Australia', 'S50_4713', '2002 Yamaha YZR M1', 1, 1),
#  ('Australia', 'S700_1691', 'American Airlines: B767-300', 2, 3),
#  ('Australia', 'S700_2047', 'HMS Bounty', 2, 2),
#  ('Australia', 'S700_2466', 'America West Airlines B757-200', 2, 2),
#  ('Australia', 'S700_2824', '1982 Camaro Z28', 1, 1),
#  ('Australia', 'S700_2834', 'ATA: B757-300', 2, 3),
#  ('Australia', 'S700_3167', 'F/A 18 Hornet 1/72', 2, 3),
#  ('Australia', 'S700_4002', 'American Airlines: MD-11S', 1, 1),
#  ('Australia', 'S72_1253', 'Boeing X-32A JSF', 2, 2),
#  ('Austria', 'S10_1678', '1969 Harley Davidson Ultimate Chopper', 1, 1),
#  ('Austria', 'S10_4757', '1972 Alfa Romeo GTA', 1, 1),
#  ('Austria', 'S10_4962', '1962 LanciaA Delta 16V', 1, 1),
#  ('Austria', 'S12_1099', '1968 Ford Mustang', 1, 2),
#  ('Austria', 'S12_1666', '1958 Setra Bus', 1, 1),
#  ('Austria', 'S12_2823', '2002 Suzuki XREO', 1, 1),
#  ('Austria', 'S12_3380', '1968 Dodge Charger', 2, 3),
#  ('Austria', 'S12_3990', '1970 Plymouth Hemi Cuda', 1, 2),
#  ('Austria', 'S12_4675', '1969 Dodge Charger', 2, 3),
#  ('Austria', 'S18_1097', '1940 Ford Pickup Truck', 1, 1),
#  ('Austria', 'S18_1129', '1993 Mazda RX-7', 1, 1),
#  ('Austria', 'S18_1589', '1965 Aston Martin DB5', 1, 1),
#  ('Austria', 'S18_1662', '1980s Black Hawk Helicopter', 1, 1),
#  ('Austria', 'S18_1889', '1948 Porsche 356-A Roadster', 2, 2),
#  ('Austria', 'S18_1984', '1995 Honda Civic', 1, 1),
#  ('Austria', 'S18_2870', '1999 Indy 500 Monte Carlo SS', 1, 1),
#  ('Austria', 'S18_2957', '1934 Ford V8 Coupe', 2, 2),
#  ('Austria', 'S18_3029', '1999 Yamaha Speed Boat', 1, 1),
#  ('Austria', 'S18_3136', '18th Century Vintage Horse Carriage', 1, 1),
#  ('Austria', 'S18_3232', '1992 Ferrari 360 Spider red', 1, 1),
#  ('Austria', 'S18_3320', '1917 Maxwell Touring Car', 1, 1),
#  ('Austria', 'S18_3685', '1948 Porsche Type 356 Roadster', 1, 1),
#  ('Austria', 'S18_3856', '1941 Chevrolet Special Deluxe Cabriolet', 1, 1),
#  ('Austria', 'S18_4600', '1940s Ford truck', 1, 1),
#  ('Austria', 'S18_4668', '1939 Cadillac Limousine', 1, 1),
#  ('Austria', 'S24_2360', '1982 Ducati 900 Monster', 1, 1),
#  ('Austria', 'S24_2841', '1900s Vintage Bi-Plane', 1, 1),
#  ('Austria', 'S24_2972', '1982 Lamborghini Diablo', 1, 1),
#  ('Austria', 'S24_3151', '1912 Ford Model T Delivery Wagon', 1, 1),
#  ('Austria', 'S24_3371', '1971 Alpine Renault 1600s', 1, 1),
#  ('Austria', 'S24_3420', '1937 Horch 930V Limousine', 1, 1),
#  ('Austria', 'S24_3816', '1940 Ford Delivery Sedan', 1, 1),
#  ('Austria', 'S24_3856', '1956 Porsche 356A Coupe', 2, 2),
#  ('Austria', 'S24_3949', 'Corsair F4U ( Bird Cage)', 1, 1),
#  ('Austria', 'S24_4258', '1936 Chrysler Airflow', 1, 1),
#  ('Austria', 'S32_1268', '1980ÔÇÖs GM Manhattan Express', 1, 1),
#  ('Austria', 'S32_3522', '1996 Peterbilt 379 Stake Bed with Outrigger', 1, 1),
#  ('Austria', 'S32_4485', '1974 Ducati 350 Mk3 Desmo', 1, 1),
#  ('Austria', 'S50_4713', '2002 Yamaha YZR M1', 1, 1),
#  ('Austria', 'S700_1138', 'The Schooner Bluenose', 1, 1),
#  ('Austria', 'S700_2047', 'HMS Bounty', 1, 1),
#  ('Austria', 'S700_2610', 'The USS Constitution Ship', 1, 1),
#  ('Austria', 'S700_2824', '1982 Camaro Z28', 1, 1),
#  ('Austria', 'S700_3167', 'F/A 18 Hornet 1/72', 1, 1),
#  ('Austria', 'S700_4002', 'American Airlines: MD-11S', 1, 1),
#  ('Austria', 'S72_1253', 'Boeing X-32A JSF', 1, 1),
#  ('Belgium', 'S10_4757', '1972 Alfa Romeo GTA', 1, 1),
#  ('Belgium', 'S18_1662', '1980s Black Hawk Helicopter', 1, 1),
#  ('Belgium', 'S18_1984', '1995 Honda Civic', 1, 1),
#  ('Belgium', 'S18_2870', '1999 Indy 500 Monte Carlo SS', 1, 1),
#  ('Belgium', 'S18_2949', '1913 Ford Model T Speedster', 1, 1),
#  ('Belgium', 'S18_2957', '1934 Ford V8 Coupe', 1, 1),
#  ('Belgium', 'S18_3029', '1999 Yamaha Speed Boat', 2, 2),
#  ('Belgium', 'S18_3136', '18th Century Vintage Horse Carriage', 1, 1),
#  ('Belgium', 'S18_3140', '1903 Ford Model A', 1, 2),
#  ('Belgium', 'S18_3232', '1992 Ferrari 360 Spider red', 1, 1),
#  ('Belgium', 'S18_3259', 'Collectable Wooden Train', 1, 2),
#  ('Belgium', 'S18_3320', '1917 Maxwell Touring Car', 1, 1),
#  ('Belgium', 'S18_3856', '1941 Chevrolet Special Deluxe Cabriolet', 2, 2),
#  ('Belgium', 'S18_4522', '1904 Buick Runabout', 1, 2),
#  ('Belgium', 'S24_2011', '18th century schooner', 1, 2),
#  ('Belgium', 'S24_3151', '1912 Ford Model T Delivery Wagon', 1, 1),
#  ('Belgium', 'S24_3816', '1940 Ford Delivery Sedan', 1, 1),
#  ('Belgium', 'S24_4258', '1936 Chrysler Airflow', 1, 1),
#  ('Belgium', 'S32_3207', "1950's Chicago Surface Lines Streetcar", 1, 1),
#  ('Belgium', 'S32_4289', '1928 Ford Phaeton Deluxe', 1, 1),
#  ('Belgium', 'S700_1138', 'The Schooner Bluenose', 1, 1),
#  ('Belgium', 'S700_1938', 'The Mayflower', 1, 2),
#  ('Belgium', 'S700_2610', 'The USS Constitution Ship', 1, 1),
#  ('Belgium', 'S700_3505', 'The Titanic', 1, 1),
#  ('Belgium', 'S700_3962', 'The Queen Mary', 1, 1),
#  ('Belgium', 'S72_3212', 'Pont Yacht', 1, 1),
#  ('Canada', 'S10_1949', '1952 Alpine Renault 1300', 2, 2),
#  ('Canada', 'S10_4757', '1972 Alfa Romeo GTA', 2, 2),
#  ('Canada', 'S10_4962', '1962 LanciaA Delta 16V', 2, 2),
#  ('Canada', 'S12_1666', '1958 Setra Bus', 2, 3),
#  ('Canada', 'S18_1097', '1940 Ford Pickup Truck', 2, 2),
#  ('Canada', 'S18_1129', '1993 Mazda RX-7', 1, 1),
#  ('Canada', 'S18_1984', '1995 Honda Civic', 1, 1),
#  ('Canada', 'S18_2319', '1964 Mercedes Tour Bus', 1, 1),
#  ('Canada', 'S18_2432', '1926 Ford Fire Engine', 1, 1),
#  ('Canada', 'S18_2581', 'P-51-D Mustang', 1, 1),
#  ('Canada', 'S18_2949', '1913 Ford Model T Speedster', 1, 1),
#  ('Canada', 'S18_2957', '1934 Ford V8 Coupe', 1, 1),
#  ('Canada', 'S18_3029', '1999 Yamaha Speed Boat', 1, 1),
#  ('Canada', 'S18_3136', '18th Century Vintage Horse Carriage', 1, 1),
#  ('Canada', 'S18_3232', '1992 Ferrari 360 Spider red', 2, 2),
#  ('Canada', 'S18_3320', '1917 Maxwell Touring Car', 1, 1),
#  ('Canada', 'S18_3856', '1941 Chevrolet Special Deluxe Cabriolet', 1, 1),
#  ('Canada', 'S18_4522', '1904 Buick Runabout', 2, 2),
#  ('Canada', 'S18_4600', '1940s Ford truck', 2, 2),
#  ('Canada', 'S18_4668', '1939 Cadillac Limousine', 2, 2),
#  ('Canada', 'S24_1785', '1928 British Royal Navy Airplane', 1, 1),
#  ('Canada', 'S24_2011', '18th century schooner', 2, 2),
#  ('Canada', 'S24_2300', '1962 Volkswagen Microbus', 1, 1),
#  ('Canada', 'S24_2972', '1982 Lamborghini Diablo', 1, 1),
#  ('Canada', 'S24_3151', '1912 Ford Model T Delivery Wagon', 2, 2),
#  ('Canada', 'S24_3816', '1940 Ford Delivery Sedan', 1, 1),
#  ('Canada', 'S24_3949', 'Corsair F4U ( Bird Cage)', 1, 1),
#  ('Canada', 'S24_4258', '1936 Chrysler Airflow', 1, 1),
#  ('Canada', 'S24_4278', '1900s Vintage Tri-Plane', 1, 1),
#  ('Canada', 'S32_1268', '1980ÔÇÖs GM Manhattan Express', 2, 2),
#  ('Canada', 'S32_1374', '1997 BMW F650 ST', 1, 1),
#  ('Canada', 'S32_2509', '1954 Greyhound Scenicruiser', 1, 1),
#  ('Canada', 'S32_3522', '1996 Peterbilt 379 Stake Bed with Outrigger', 2, 3),
#  ('Canada', 'S32_4289', '1928 Ford Phaeton Deluxe', 1, 1),
#  ('Canada', 'S50_1341', '1930 Buick Marquette Phaeton', 1, 1),
#  ('Canada', 'S700_1138', 'The Schooner Bluenose', 2, 2),
#  ('Canada', 'S700_1691', 'American Airlines: B767-300', 1, 1),
#  ('Canada', 'S700_2047', 'HMS Bounty', 1, 1),
#  ('Canada', 'S700_2466', 'America West Airlines B757-200', 1, 1),
#  ('Canada', 'S700_2610', 'The USS Constitution Ship', 2, 2),
#  ('Canada', 'S700_2824', '1982 Camaro Z28', 2, 3),
#  ('Canada', 'S700_2834', 'ATA: B757-300', 1, 1),
#  ('Canada', 'S700_3167', 'F/A 18 Hornet 1/72', 1, 1),
#  ('Canada', 'S700_3505', 'The Titanic', 2, 2),
#  ('Canada', 'S700_3962', 'The Queen Mary', 2, 2),
#  ('Canada', 'S700_4002', 'American Airlines: MD-11S', 1, 1),
#  ('Canada', 'S72_1253', 'Boeing X-32A JSF', 1, 1),
#  ('Canada', 'S72_3212', 'Pont Yacht', 2, 2),
#  ('Denmark', 'S10_4757', '1972 Alfa Romeo GTA', 1, 1),
#  ('Denmark', 'S12_1099', '1968 Ford Mustang', 1, 1),
#  ('Denmark', 'S12_1108', '2001 Ferrari Enzo', 2, 2),
#  ('Denmark', 'S12_3148', '1969 Corvair Monza', 1, 1),
#  ('Denmark', 'S12_3380', '1968 Dodge Charger', 1, 1),
#  ('Denmark', 'S12_3891', '1969 Ford Falcon', 2, 2),
#  ('Denmark', 'S12_3990', '1970 Plymouth Hemi Cuda', 1, 1),
#  ('Denmark', 'S12_4473', '1957 Chevy Pickup', 1, 1),
#  ('Denmark', 'S18_1129', '1993 Mazda RX-7', 2, 2),
#  ('Denmark', 'S18_1342', '1937 Lincoln Berline', 1, 1),
#  ('Denmark', 'S18_1367', '1936 Mercedes-Benz 500K Special Roadster', 1, 1),
#  ('Denmark', 'S18_1589', '1965 Aston Martin DB5', 1, 1),
#  ('Denmark', 'S18_1662', '1980s Black Hawk Helicopter', 1, 1),
#  ('Denmark', 'S18_1984', '1995 Honda Civic', 2, 2),
#  ('Denmark', 'S18_2238', '1998 Chrysler Plymouth Prowler', 1, 1),
#  ('Denmark', 'S18_2581', 'P-51-D Mustang', 1, 1),
#  ('Denmark', 'S18_2870', '1999 Indy 500 Monte Carlo SS', 1, 1),
#  ('Denmark', 'S18_3029', '1999 Yamaha Speed Boat', 1, 1),
#  ('Denmark', 'S18_3140', '1903 Ford Model A', 2, 2),
#  ('Denmark', 'S18_3259', 'Collectable Wooden Train', 2, 2),
#  ('Denmark', 'S18_3278', '1969 Dodge Super Bee', 1, 1),
#  ('Denmark', 'S18_3482', '1976 Ford Gran Torino', 1, 1),
#  ('Denmark', 'S18_3685', '1948 Porsche Type 356 Roadster', 2, 2),
#  ('Denmark', 'S18_4027', '1970 Triumph Spitfire', 1, 1),
#  ('Denmark', 'S18_4522', '1904 Buick Runabout', 1, 1),
#  ('Denmark', 'S18_4721', '1957 Corvette Convertible', 1, 1),
#  ('Denmark', 'S18_4933', '1957 Ford Thunderbird', 1, 1),
#  ('Denmark', 'S24_1046', '1970 Chevy Chevelle SS 454', 1, 1),
#  ('Denmark', 'S24_1444', '1970 Dodge Coronet', 1, 1),
#  ('Denmark', 'S24_1628', '1966 Shelby Cobra 427 S/C', 1, 1),
#  ('Denmark', 'S24_2011', '18th century schooner', 1, 1),
#  ('Denmark', 'S24_2766', '1949 Jaguar XK 120', 1, 1),
#  ('Denmark', 'S24_2840', '1958 Chevy Corvette Limited Edition', 1, 1),
#  ('Denmark', 'S24_2887', '1952 Citroen-15CV', 1, 1),
#  ('Denmark', 'S24_3151', '1912 Ford Model T Delivery Wagon', 1, 1),
#  ('Denmark', 'S24_3191', '1969 Chevrolet Camaro Z28', 1, 1),
#  ('Denmark', 'S24_3371', '1971 Alpine Renault 1600s', 1, 1),
#  ('Denmark', 'S24_3432', '2002 Chevy Corvette', 1, 1),
#  ('Denmark', 'S24_3816', '1940 Ford Delivery Sedan', 1, 1),
#  ('Denmark', 'S24_4048', '1992 Porsche Cayenne Turbo Silver', 1, 1),
#  ('Denmark', 'S24_4620', '1961 Chevrolet Impala', 1, 1),
#  ('Denmark', 'S32_3207', "1950's Chicago Surface Lines Streetcar", 1, 1),
#  ('Denmark', 'S50_1392', 'Diamond T620 Semi-Skirted Tanker', 1, 1),
#  ('Denmark', 'S50_1514', '1962 City of Detroit Streetcar', 1, 1),
#  ('Denmark', 'S700_1138', 'The Schooner Bluenose', 1, 1),
#  ('Denmark', 'S700_1938', 'The Mayflower', 2, 3),
#  ('Denmark', 'S700_2610', 'The USS Constitution Ship', 1, 2),
#  ('Denmark', 'S700_3505', 'The Titanic', 1, 2),
#  ('Denmark', 'S700_3962', 'The Queen Mary', 1, 2),
#  ('Denmark', 'S72_3212', 'Pont Yacht', 1, 2),
#  ('Finland', 'S10_1678', '1969 Harley Davidson Ultimate Chopper', 1, 1),
#  ('Finland', 'S10_4698', '2003 Harley-Davidson Eagle Drag Bike', 1, 1),
#  ('Finland', 'S10_4757', '1972 Alfa Romeo GTA', 2, 2),
#  ('Finland', 'S12_1099', '1968 Ford Mustang', 1, 1),
#  ('Finland', 'S12_1108', '2001 Ferrari Enzo', 1, 1),
#  ('Finland', 'S12_2823', '2002 Suzuki XREO', 1, 1),
#  ('Finland', 'S12_3148', '1969 Corvair Monza', 1, 1),
#  ('Finland', 'S12_3380', '1968 Dodge Charger', 1, 1),
#  ('Finland', 'S12_3891', '1969 Ford Falcon', 1, 1),
#  ('Finland', 'S12_3990', '1970 Plymouth Hemi Cuda', 2, 2),
#  ('Finland', 'S12_4473', '1957 Chevy Pickup', 2, 2),
#  ('Finland', 'S12_4675', '1969 Dodge Charger', 3, 3),
#  ('Finland', 'S18_1129', '1993 Mazda RX-7', 1, 1),
#  ('Finland', 'S18_1662', '1980s Black Hawk Helicopter', 2, 2),
#  ('Finland', 'S18_1889', '1948 Porsche 356-A Roadster', 3, 3),
#  ('Finland', 'S18_1984', '1995 Honda Civic', 1, 1),
#  ('Finland', 'S18_2238', '1998 Chrysler Plymouth Prowler', 2, 2),
#  ('Finland', 'S18_2319', '1964 Mercedes Tour Bus', 2, 2),
#  ('Finland', 'S18_2432', '1926 Ford Fire Engine', 1, 1),
#  ('Finland', 'S18_3029', '1999 Yamaha Speed Boat', 2, 2),
#  ('Finland', 'S18_3232', '1992 Ferrari 360 Spider red', 3, 4),
#  ('Finland', 'S18_3278', '1969 Dodge Super Bee', 1, 1),
#  ('Finland', 'S18_3482', '1976 Ford Gran Torino', 1, 1),
#  ('Finland', 'S18_3782', '1957 Vespa GS150', 2, 2),
#  ('Finland', 'S18_3856', '1941 Chevrolet Special Deluxe Cabriolet', 2, 2),
#  ('Finland', 'S18_4027', '1970 Triumph Spitfire', 1, 1),
#  ('Finland', 'S18_4721', '1957 Corvette Convertible', 2, 2),
#  ('Finland', 'S24_1444', '1970 Dodge Coronet', 1, 1),
#  ('Finland', 'S24_1578', '1997 BMW R 1100 S', 1, 1),
#  ('Finland', 'S24_2000', '1960 BSA Gold Star DBD34', 1, 1),
#  ('Finland', 'S24_2300', '1962 Volkswagen Microbus', 1, 1),
#  ('Finland', 'S24_2360', '1982 Ducati 900 Monster', 2, 2),
#  ('Finland', 'S24_2840', '1958 Chevy Corvette Limited Edition', 2, 2),
#  ('Finland', 'S24_2841', '1900s Vintage Bi-Plane', 2, 2),
#  ('Finland', 'S24_2972', '1982 Lamborghini Diablo', 1, 1),
#  ('Finland', 'S24_3151', '1912 Ford Model T Delivery Wagon', 1, 1),
#  ('Finland', 'S24_3371', '1971 Alpine Renault 1600s', 1, 1),
#  ('Finland', 'S24_3420', '1937 Horch 930V Limousine', 2, 2),
#  ('Finland', 'S24_3816', '1940 Ford Delivery Sedan', 2, 2),
#  ('Finland', 'S24_3856', '1956 Porsche 356A Coupe', 2, 2),
#  ('Finland', 'S24_3949', 'Corsair F4U ( Bird Cage)', 2, 2),
#  ('Finland', 'S24_4048', '1992 Porsche Cayenne Turbo Silver', 1, 1),
#  ('Finland', 'S24_4620', '1961 Chevrolet Impala', 2, 2),
#  ('Finland', 'S32_1268', '1980ÔÇÖs GM Manhattan Express', 1, 1),
#  ('Finland', 'S32_1374', '1997 BMW F650 ST', 1, 1),
#  ('Finland', 'S32_2206', '1982 Ducati 996 R', 1, 1),
#  ('Finland', 'S32_2509', '1954 Greyhound Scenicruiser', 2, 2),
#  ('Finland', 'S32_3207', "1950's Chicago Surface Lines Streetcar", 1, 1),
#  ('Finland', 'S32_4485', '1974 Ducati 350 Mk3 Desmo', 1, 1),
#  ('Finland', 'S50_1392', 'Diamond T620 Semi-Skirted Tanker', 2, 2),
#  ('Finland', 'S50_1514', '1962 City of Detroit Streetcar', 1, 1),
#  ('Finland', 'S50_4713', '2002 Yamaha YZR M1', 1, 1),
#  ('Finland', 'S700_1138', 'The Schooner Bluenose', 1, 1),
#  ('Finland', 'S700_2047', 'HMS Bounty', 2, 2),
#  ('Finland', 'S700_2466', 'America West Airlines B757-200', 1, 1),
#  ('Finland', 'S700_2610', 'The USS Constitution Ship', 1, 1),
#  ('Finland', 'S700_3167', 'F/A 18 Hornet 1/72', 1, 1),
#  ('Finland', 'S700_3505', 'The Titanic', 1, 1),
#  ('Finland', 'S700_3962', 'The Queen Mary', 1, 1),
#  ('Finland', 'S700_4002', 'American Airlines: MD-11S', 2, 2),
#  ('Finland', 'S72_1253', 'Boeing X-32A JSF', 2, 2),
#  ('Finland', 'S72_3212', 'Pont Yacht', 1, 1),
#  ('France', 'S10_1678', '1969 Harley Davidson Ultimate Chopper', 5, 6),
#  ('France', 'S10_1949', '1952 Alpine Renault 1300', 2, 2),
#  ('France', 'S10_2016', '1996 Moto Guzzi 1100i', 5, 5),
#  ('France', 'S10_4698', '2003 Harley-Davidson Eagle Drag Bike', 3, 3),
#  ('France', 'S10_4757', '1972 Alfa Romeo GTA', 3, 3),
#  ('France', 'S10_4962', '1962 LanciaA Delta 16V', 3, 3),
#  ('France', 'S12_1099', '1968 Ford Mustang', 3, 3),
#  ('France', 'S12_1108', '2001 Ferrari Enzo', 4, 4),
#  ('France', 'S12_1666', '1958 Setra Bus', 2, 3),
#  ('France', 'S12_2823', '2002 Suzuki XREO', 5, 6),
#  ('France', 'S12_3148', '1969 Corvair Monza', 2, 2),
#  ('France', 'S12_3380', '1968 Dodge Charger', 1, 1),
#  ('France', 'S12_3891', '1969 Ford Falcon', 3, 3),
#  ('France', 'S12_3990', '1970 Plymouth Hemi Cuda', 2, 2),
#  ('France', 'S12_4473', '1957 Chevy Pickup', 2, 2),
#  ('France', 'S12_4675', '1969 Dodge Charger', 2, 2),
#  ('France', 'S18_1097', '1940 Ford Pickup Truck', 2, 2),
#  ('France', 'S18_1129', '1993 Mazda RX-7', 3, 3),
#  ('France', 'S18_1342', '1937 Lincoln Berline', 3, 3),
#  ('France', 'S18_1367', '1936 Mercedes-Benz 500K Special Roadster', 3, 3),
#  ('France', 'S18_1589', '1965 Aston Martin DB5', 3, 4),
#  ('France', 'S18_1662', '1980s Black Hawk Helicopter', 2, 2),
#  ('France', 'S18_1749', '1917 Grand Touring Sedan', 3, 3),
#  ('France', 'S18_1889', '1948 Porsche 356-A Roadster', 2, 2),
#  ('France', 'S18_1984', '1995 Honda Civic', 3, 3),
#  ('France', 'S18_2238', '1998 Chrysler Plymouth Prowler', 2, 2),
#  ('France', 'S18_2248', '1911 Ford Town Car', 3, 3),
#  ('France', 'S18_2319', '1964 Mercedes Tour Bus', 2, 2),
#  ('France', 'S18_2325', '1932 Model A Ford J-Coupe', 4, 4),
#  ('France', 'S18_2432', '1926 Ford Fire Engine', 3, 3),
#  ('France', 'S18_2581', 'P-51-D Mustang', 2, 2),
#  ('France', 'S18_2625', '1936 Harley Davidson El Knucklehead', 5, 5),
#  ('France', 'S18_2795', '1928 Mercedes-Benz SSK', 4, 4),
#  ('France', 'S18_2870', '1999 Indy 500 Monte Carlo SS', 3, 4),
#  ('France', 'S18_2949', '1913 Ford Model T Speedster', 1, 1),
#  ('France', 'S18_2957', '1934 Ford V8 Coupe', 1, 1),
#  ('France', 'S18_3029', '1999 Yamaha Speed Boat', 2, 2),
#  ('France', 'S18_3136', '18th Century Vintage Horse Carriage', 1, 1),
#  ('France', 'S18_3140', '1903 Ford Model A', 2, 2),
#  ('France', 'S18_3232', '1992 Ferrari 360 Spider red', 5, 5),
#  ('France', 'S18_3259', 'Collectable Wooden Train', 2, 2),
#  ('France', 'S18_3278', '1969 Dodge Super Bee', 2, 3),
#  ('France', 'S18_3320', '1917 Maxwell Touring Car', 2, 2),
#  ('France', 'S18_3482', '1976 Ford Gran Torino', 2, 3),
#  ('France', 'S18_3685', '1948 Porsche Type 356 Roadster', 2, 3),
#  ('France', 'S18_3782', '1957 Vespa GS150', 4, 6),
#  ('France', 'S18_3856', '1941 Chevrolet Special Deluxe Cabriolet', 2, 2),
#  ('France', 'S18_4409', '1932 Alfa Romeo 8C2300 Spider Sport', 3, 3),
#  ('France', 'S18_4522', '1904 Buick Runabout', 2, 2),
#  ('France', 'S18_4600', '1940s Ford truck', 3, 3),
#  ('France', 'S18_4668', '1939 Cadillac Limousine', 2, 2),
#  ('France', 'S18_4721', '1957 Corvette Convertible', 3, 4),
#  ('France', 'S18_4933', '1957 Ford Thunderbird', 3, 3),
#  ('France', 'S24_1046', '1970 Chevy Chevelle SS 454', 2, 2),
#  ('France', 'S24_1444', '1970 Dodge Coronet', 2, 2),
#  ('France', 'S24_1578', '1997 BMW R 1100 S', 4, 4),
#  ('France', 'S24_1628', '1966 Shelby Cobra 427 S/C', 3, 4),
#  ('France', 'S24_1785', '1928 British Royal Navy Airplane', 2, 2),
#  ('France', 'S24_1937', '1939 Chevrolet Deluxe Coupe', 4, 4),
#  ('France', 'S24_2000', '1960 BSA Gold Star DBD34', 4, 5),
#  ('France', 'S24_2011', '18th century schooner', 2, 2),
#  ('France', 'S24_2022', '1938 Cadillac V-16 Presidential Limousine', 5, 5),
#  ('France', 'S24_2300', '1962 Volkswagen Microbus', 3, 3),
#  ('France', 'S24_2360', '1982 Ducati 900 Monster', 4, 6),
#  ('France', 'S24_2766', '1949 Jaguar XK 120', 2, 2),
#  ('France', 'S24_2840', '1958 Chevy Corvette Limited Edition', 2, 2),
#  ('France', 'S24_2841', '1900s Vintage Bi-Plane', 2, 2),
#  ('France', 'S24_2887', '1952 Citroen-15CV', 2, 2),
#  ('France', 'S24_2972', '1982 Lamborghini Diablo', 2, 2),
#  ('France', 'S24_3151', '1912 Ford Model T Delivery Wagon', 2, 2),
#  ('France', 'S24_3191', '1969 Chevrolet Camaro Z28', 2, 2),
#  ('France', 'S24_3371', '1971 Alpine Renault 1600s', 2, 2),
#  ('France', 'S24_3420', '1937 Horch 930V Limousine', 2, 2),
#  ('France', 'S24_3432', '2002 Chevy Corvette', 1, 1),
#  ('France', 'S24_3816', '1940 Ford Delivery Sedan', 1, 1),
#  ('France', 'S24_3856', '1956 Porsche 356A Coupe', 2, 2),
#  ('France', 'S24_3949', 'Corsair F4U ( Bird Cage)', 3, 3),
#  ('France', 'S24_3969', '1936 Mercedes Benz 500k Roadster', 1, 1),
#  ('France', 'S24_4048', '1992 Porsche Cayenne Turbo Silver', 2, 2),
#  ('France', 'S24_4258', '1936 Chrysler Airflow', 1, 1),
#  ('France', 'S24_4278', '1900s Vintage Tri-Plane', 2, 3),
#  ('France', 'S24_4620', '1961 Chevrolet Impala', 4, 5),
#  ('France', 'S32_1268', '1980ÔÇÖs GM Manhattan Express', 3, 3),
#  ('France', 'S32_1374', '1997 BMW F650 ST', 1, 2),
#  ('France', 'S32_2206', '1982 Ducati 996 R', 4, 7),
#  ('France', 'S32_2509', '1954 Greyhound Scenicruiser', 3, 3),
#  ('France', 'S32_3207', "1950's Chicago Surface Lines Streetcar", 2, 2),
#  ('France', 'S32_3522', '1996 Peterbilt 379 Stake Bed with Outrigger', 2, 2),
#  ('France', 'S32_4289', '1928 Ford Phaeton Deluxe', 2, 3),
#  ('France', 'S32_4485', '1974 Ducati 350 Mk3 Desmo', 4, 6),
#  ('France', 'S50_1341', '1930 Buick Marquette Phaeton', 2, 3),
#  ('France', 'S50_1392', 'Diamond T620 Semi-Skirted Tanker', 4, 4),
#  ('France', 'S50_1514', '1962 City of Detroit Streetcar', 3, 3),
#  ('France', 'S50_4713', '2002 Yamaha YZR M1', 5, 7),
#  ('France', 'S700_1138', 'The Schooner Bluenose', 2, 2),
#  ('France', 'S700_1691', 'American Airlines: B767-300', 2, 3),
#  ('France', 'S700_1938', 'The Mayflower', 2, 2),
#  ('France', 'S700_2047', 'HMS Bounty', 2, 2),
#  ('France', 'S700_2466', 'America West Airlines B757-200', 3, 4),
#  ('France', 'S700_2610', 'The USS Constitution Ship', 2, 2),
#  ('France', 'S700_2824', '1982 Camaro Z28', 3, 4),
#  ('France', 'S700_2834', 'ATA: B757-300', 2, 3),
#  ('France', 'S700_3167', 'F/A 18 Hornet 1/72', 2, 3),
#  ('France', 'S700_3505', 'The Titanic', 3, 3),
#  ('France', 'S700_3962', 'The Queen Mary', 3, 3),
#  ('France', 'S700_4002', 'American Airlines: MD-11S', 3, 3),
#  ('France', 'S72_1253', 'Boeing X-32A JSF', 2, 2),
#  ('France', 'S72_3212', 'Pont Yacht', 3, 3),
#  ('Germany', 'S12_1099', '1968 Ford Mustang', 2, 3),
#  ('Germany', 'S12_3148', '1969 Corvair Monza', 1, 1),
#  ('Germany', 'S12_3380', '1968 Dodge Charger', 2, 3),
#  ('Germany', 'S12_3990', '1970 Plymouth Hemi Cuda', 2, 3),
#  ('Germany', 'S12_4675', '1969 Dodge Charger', 2, 2),
#  ('Germany', 'S18_1129', '1993 Mazda RX-7', 1, 1),
#  ('Germany', 'S18_1662', '1980s Black Hawk Helicopter', 1, 1),
#  ('Germany', 'S18_1889', '1948 Porsche 356-A Roadster', 2, 2),
#  ('Germany', 'S18_1984', '1995 Honda Civic', 1, 1),
#  ('Germany', 'S18_2238', '1998 Chrysler Plymouth Prowler', 1, 1),
#  ('Germany', 'S18_2325', '1932 Model A Ford J-Coupe', 1, 1),
#  ('Germany', 'S18_2795', '1928 Mercedes-Benz SSK', 1, 1),
#  ('Germany', 'S18_3029', '1999 Yamaha Speed Boat', 1, 1),
#  ('Germany', 'S18_3232', '1992 Ferrari 360 Spider red', 1, 1),
#  ('Germany', 'S18_3278', '1969 Dodge Super Bee', 2, 3),
#  ('Germany', 'S18_3320', '1917 Maxwell Touring Car', 1, 1),
#  ('Germany', 'S18_3482', '1976 Ford Gran Torino', 2, 3),
#  ('Germany', 'S18_3782', '1957 Vespa GS150', 1, 2),
#  ('Germany', 'S18_3856', '1941 Chevrolet Special Deluxe Cabriolet', 1, 1),
#  ('Germany', 'S18_4027', '1970 Triumph Spitfire', 1, 1),
#  ('Germany', 'S18_4600', '1940s Ford truck', 1, 1),
#  ('Germany', 'S18_4721', '1957 Corvette Convertible', 1, 2),
#  ('Germany', 'S24_1444', '1970 Dodge Coronet', 1, 1),
#  ('Germany', 'S24_1937', '1939 Chevrolet Deluxe Coupe', 1, 1),
#  ('Germany', 'S24_2022', '1938 Cadillac V-16 Presidential Limousine', 1, 1),
#  ('Germany', 'S24_2841', '1900s Vintage Bi-Plane', 1, 1),
#  ('Germany', 'S24_2972', '1982 Lamborghini Diablo', 1, 1),
#  ('Germany', 'S24_3371', '1971 Alpine Renault 1600s', 2, 3),
#  ('Germany', 'S24_3420', '1937 Horch 930V Limousine', 1, 1),
#  ('Germany', 'S24_3816', '1940 Ford Delivery Sedan', 1, 1),
#  ('Germany', 'S24_3856', '1956 Porsche 356A Coupe', 1, 1),
#  ('Germany', 'S24_3949', 'Corsair F4U ( Bird Cage)', 1, 1),
#  ('Germany', 'S24_4048', '1992 Porsche Cayenne Turbo Silver', 1, 1),
#  ('Germany', 'S24_4620', '1961 Chevrolet Impala', 1, 2),
#  ('Germany', 'S32_2206', '1982 Ducati 996 R', 1, 1),
#  ('Germany', 'S32_3207', "1950's Chicago Surface Lines Streetcar", 1, 1),
#  ('Germany', 'S50_1341', '1930 Buick Marquette Phaeton', 1, 1),
#  ('Germany', 'S50_1392', 'Diamond T620 Semi-Skirted Tanker', 1, 1),
#  ('Germany', 'S50_1514', '1962 City of Detroit Streetcar', 1, 1),
#  ('Germany', 'S700_1691', 'American Airlines: B767-300', 1, 1),
#  ('Germany', 'S700_2047', 'HMS Bounty', 1, 1),
#  ('Germany', 'S700_2466', 'America West Airlines B757-200', 1, 1),
#  ('Germany', 'S700_3167', 'F/A 18 Hornet 1/72', 1, 1),
#  ('Germany', 'S700_4002', 'American Airlines: MD-11S', 1, 1),
#  ('Germany', 'S72_1253', 'Boeing X-32A JSF', 1, 1),
#  ('Hong Kong', 'S18_2581', 'P-51-D Mustang', 1, 2),
#  ('Hong Kong', 'S24_1785', '1928 British Royal Navy Airplane', 1, 2),
#  ('Hong Kong', 'S24_3949', 'Corsair F4U ( Bird Cage)', 1, 1),
#  ('Hong Kong', 'S24_4278', '1900s Vintage Tri-Plane', 1, 2),
#  ('Hong Kong', 'S32_1374', '1997 BMW F650 ST', 1, 1),
#  ('Hong Kong', 'S32_4289', '1928 Ford Phaeton Deluxe', 1, 2),
#  ('Hong Kong', 'S50_1341', '1930 Buick Marquette Phaeton', 1, 1),
#  ('Hong Kong', 'S700_1691', 'American Airlines: B767-300', 1, 1),
#  ('Hong Kong', 'S700_2466', 'America West Airlines B757-200', 1, 1),
#  ('Hong Kong', 'S700_2834', 'ATA: B757-300', 1, 1),
#  ('Hong Kong', 'S700_3167', 'F/A 18 Hornet 1/72', 1, 1),
#  ('Hong Kong', 'S700_4002', 'American Airlines: MD-11S', 1, 1),
#  ('Ireland', 'S12_1108', '2001 Ferrari Enzo', 1, 1),
#  ('Ireland', 'S12_3148', '1969 Corvair Monza', 1, 1),
#  ('Ireland', 'S12_3891', '1969 Ford Falcon', 1, 1),
#  ('Ireland', 'S18_2581', 'P-51-D Mustang', 1, 1),
#  ('Ireland', 'S18_4027', '1970 Triumph Spitfire', 1, 1),
#  ('Ireland', 'S24_1444', '1970 Dodge Coronet', 1, 1),
#  ('Ireland', 'S24_1785', '1928 British Royal Navy Airplane', 1, 1),
#  ('Ireland', 'S24_2000', '1960 BSA Gold Star DBD34', 1, 1),
#  ('Ireland', 'S24_4048', '1992 Porsche Cayenne Turbo Silver', 1, 1),
#  ('Ireland', 'S24_4278', '1900s Vintage Tri-Plane', 1, 1),
#  ('Ireland', 'S32_1374', '1997 BMW F650 ST', 1, 1),
#  ('Ireland', 'S32_3207', "1950's Chicago Surface Lines Streetcar", 1, 1),
#  ('Ireland', 'S32_4289', '1928 Ford Phaeton Deluxe', 1, 1),
#  ('Ireland', 'S50_1392', 'Diamond T620 Semi-Skirted Tanker', 1, 1),
#  ('Ireland', 'S50_1514', '1962 City of Detroit Streetcar', 1, 1),
#  ('Ireland', 'S700_2834', 'ATA: B757-300', 1, 1),
#  ('Italy', 'S10_1949', '1952 Alpine Renault 1300', 1, 1),
#  ('Italy', 'S12_1099', '1968 Ford Mustang', 1, 1),
#  ('Italy', 'S12_1108', '2001 Ferrari Enzo', 2, 2),
#  ('Italy', 'S12_3148', '1969 Corvair Monza', 2, 2),
#  ('Italy', 'S12_3380', '1968 Dodge Charger', 1, 1),
#  ('Italy', 'S12_3891', '1969 Ford Falcon', 2, 2),
#  ('Italy', 'S12_3990', '1970 Plymouth Hemi Cuda', 1, 1),
#  ('Italy', 'S12_4675', '1969 Dodge Charger', 1, 1),
#  ('Italy', 'S18_1097', '1940 Ford Pickup Truck', 1, 1),
#  ('Italy', 'S18_1129', '1993 Mazda RX-7', 1, 1),
#  ('Italy', 'S18_1342', '1937 Lincoln Berline', 2, 2),
#  ('Italy', 'S18_1367', '1936 Mercedes-Benz 500K Special Roadster', 2, 2),
#  ('Italy', 'S18_1589', '1965 Aston Martin DB5', 1, 1),
#  ('Italy', 'S18_1662', '1980s Black Hawk Helicopter', 2, 2),
#  ('Italy', 'S18_1749', '1917 Grand Touring Sedan', 2, 2),
#  ('Italy', 'S18_1889', '1948 Porsche 356-A Roadster', 1, 1),
#  ('Italy', 'S18_1984', '1995 Honda Civic', 1, 1),
#  ('Italy', 'S18_2238', '1998 Chrysler Plymouth Prowler', 1, 1),
#  ('Italy', 'S18_2248', '1911 Ford Town Car', 2, 2),
#  ('Italy', 'S18_2319', '1964 Mercedes Tour Bus', 1, 1),
#  ('Italy', 'S18_2325', '1932 Model A Ford J-Coupe', 2, 2),
#  ('Italy', 'S18_2581', 'P-51-D Mustang', 3, 3),
#  ('Italy', 'S18_2795', '1928 Mercedes-Benz SSK', 2, 2),
#  ('Italy', 'S18_2870', '1999 Indy 500 Monte Carlo SS', 1, 1),
#  ('Italy', 'S18_2949', '1913 Ford Model T Speedster', 1, 1),
#  ('Italy', 'S18_2957', '1934 Ford V8 Coupe', 2, 2),
#  ('Italy', 'S18_3029', '1999 Yamaha Speed Boat', 1, 1),
#  ('Italy', 'S18_3136', '18th Century Vintage Horse Carriage', 2, 2),
#  ('Italy', 'S18_3140', '1903 Ford Model A', 1, 1),
#  ('Italy', 'S18_3232', '1992 Ferrari 360 Spider red', 2, 2),
#  ('Italy', 'S18_3259', 'Collectable Wooden Train', 1, 1),
#  ('Italy', 'S18_3320', '1917 Maxwell Touring Car', 2, 2),
#  ('Italy', 'S18_3685', '1948 Porsche Type 356 Roadster', 1, 1),
#  ('Italy', 'S18_3856', '1941 Chevrolet Special Deluxe Cabriolet', 1, 2),
#  ('Italy', 'S18_4027', '1970 Triumph Spitfire', 1, 1),
#  ('Italy', 'S18_4409', '1932 Alfa Romeo 8C2300 Spider Sport', 2, 2),
#  ('Italy', 'S18_4522', '1904 Buick Runabout', 1, 1),
#  ('Italy', 'S18_4933', '1957 Ford Thunderbird', 1, 1),
#  ('Italy', 'S24_1444', '1970 Dodge Coronet', 1, 1),
#  ('Italy', 'S24_1628', '1966 Shelby Cobra 427 S/C', 1, 1),
#  ('Italy', 'S24_1785', '1928 British Royal Navy Airplane', 3, 4),
#  ('Italy', 'S24_1937', '1939 Chevrolet Deluxe Coupe', 2, 2),
#  ('Italy', 'S24_2000', '1960 BSA Gold Star DBD34', 1, 1),
#  ('Italy', 'S24_2011', '18th century schooner', 1, 1),
#  ('Italy', 'S24_2022', '1938 Cadillac V-16 Presidential Limousine', 2, 2),
#  ('Italy', 'S24_2841', '1900s Vintage Bi-Plane', 1, 2),
#  ('Italy', 'S24_2887', '1952 Citroen-15CV', 1, 1),
#  ('Italy', 'S24_2972', '1982 Lamborghini Diablo', 1, 1),
#  ('Italy', 'S24_3371', '1971 Alpine Renault 1600s', 1, 1),
#  ('Italy', 'S24_3420', '1937 Horch 930V Limousine', 1, 2),
#  ('Italy', 'S24_3856', '1956 Porsche 356A Coupe', 1, 1),
#  ('Italy', 'S24_3949', 'Corsair F4U ( Bird Cage)', 2, 3),
#  ('Italy', 'S24_3969', '1936 Mercedes Benz 500k Roadster', 2, 2),
#  ('Italy', 'S24_4048', '1992 Porsche Cayenne Turbo Silver', 1, 1),
#  ('Italy', 'S24_4258', '1936 Chrysler Airflow', 2, 2),
#  ('Italy', 'S24_4278', '1900s Vintage Tri-Plane', 3, 4),
#  ('Italy', 'S32_1374', '1997 BMW F650 ST', 2, 2),
#  ('Italy', 'S32_3207', "1950's Chicago Surface Lines Streetcar", 1, 1),
#  ('Italy', 'S32_4289', '1928 Ford Phaeton Deluxe', 3, 4),
#  ('Italy', 'S50_1341', '1930 Buick Marquette Phaeton', 2, 3),
#  ('Italy', 'S50_1392', 'Diamond T620 Semi-Skirted Tanker', 1, 1),
#  ('Italy', 'S50_1514', '1962 City of Detroit Streetcar', 1, 1),
#  ('Italy', 'S700_1691', 'American Airlines: B767-300', 2, 3),
#  ('Italy', 'S700_1938', 'The Mayflower', 1, 1),
#  ('Italy', 'S700_2047', 'HMS Bounty', 1, 2),
#  ('Italy', 'S700_2466', 'America West Airlines B757-200', 2, 3),
#  ('Italy', 'S700_2834', 'ATA: B757-300', 3, 4),
#  ('Italy', 'S700_3167', 'F/A 18 Hornet 1/72', 2, 3),
#  ('Italy', 'S700_4002', 'American Airlines: MD-11S', 2, 3),
#  ('Italy', 'S72_1253', 'Boeing X-32A JSF', 1, 1),
#  ('Italy', 'S72_3212', 'Pont Yacht', 1, 1),
#  ('Japan', 'S10_1949', '1952 Alpine Renault 1300', 1, 1),
#  ('Japan', 'S10_2016', '1996 Moto Guzzi 1100i', 2, 2),
#  ('Japan', 'S10_4698', '2003 Harley-Davidson Eagle Drag Bike', 2, 2),
#  ('Japan', 'S12_1666', '1958 Setra Bus', 1, 1),
#  ('Japan', 'S12_3148', '1969 Corvair Monza', 1, 1),
#  ('Japan', 'S12_3891', '1969 Ford Falcon', 1, 1),
#  ('Japan', 'S18_1097', '1940 Ford Pickup Truck', 1, 1),
#  ('Japan', 'S18_1129', '1993 Mazda RX-7', 1, 1),
#  ('Japan', 'S18_1662', '1980s Black Hawk Helicopter', 1, 1),
#  ('Japan', 'S18_1984', '1995 Honda Civic', 1, 1),
#  ('Japan', 'S18_2581', 'P-51-D Mustang', 2, 2),
#  ('Japan', 'S18_2625', '1936 Harley Davidson El Knucklehead', 2, 2),
#  ('Japan', 'S18_3140', '1903 Ford Model A', 1, 1),
#  ('Japan', 'S18_3259', 'Collectable Wooden Train', 1, 1),
#  ('Japan', 'S18_3685', '1948 Porsche Type 356 Roadster', 1, 1),
#  ('Japan', 'S18_4027', '1970 Triumph Spitfire', 1, 1),
#  ('Japan', 'S18_4522', '1904 Buick Runabout', 1, 1),
#  ('Japan', 'S18_4668', '1939 Cadillac Limousine', 1, 1),
#  ('Japan', 'S24_1578', '1997 BMW R 1100 S', 1, 1),
#  ('Japan', 'S24_1785', '1928 British Royal Navy Airplane', 2, 2),
#  ('Japan', 'S24_2000', '1960 BSA Gold Star DBD34', 1, 1),
#  ('Japan', 'S24_2011', '18th century schooner', 1, 1),
#  ('Japan', 'S24_2841', '1900s Vintage Bi-Plane', 1, 1),
#  ('Japan', 'S24_3151', '1912 Ford Model T Delivery Wagon', 1, 1),
#  ('Japan', 'S24_3420', '1937 Horch 930V Limousine', 1, 1),
#  ('Japan', 'S24_3816', '1940 Ford Delivery Sedan', 1, 1),
#  ('Japan', 'S24_3949', 'Corsair F4U ( Bird Cage)', 2, 2),
#  ('Japan', 'S24_3969', '1936 Mercedes Benz 500k Roadster', 1, 1),
#  ('Japan', 'S24_4278', '1900s Vintage Tri-Plane', 1, 1),
#  ('Japan', 'S32_1374', '1997 BMW F650 ST', 1, 1),
#  ('Japan', 'S32_3522', '1996 Peterbilt 379 Stake Bed with Outrigger', 1, 1),
#  ('Japan', 'S32_4289', '1928 Ford Phaeton Deluxe', 1, 1),
#  ('Japan', 'S50_1341', '1930 Buick Marquette Phaeton', 1, 1),
#  ('Japan', 'S50_1514', '1962 City of Detroit Streetcar', 1, 1),
#  ('Japan', 'S700_1138', 'The Schooner Bluenose', 1, 1),
#  ('Japan', 'S700_1691', 'American Airlines: B767-300', 1, 1),
#  ('Japan', 'S700_1938', 'The Mayflower', 1, 1),
#  ('Japan', 'S700_2047', 'HMS Bounty', 1, 1),
#  ('Japan', 'S700_2466', 'America West Airlines B757-200', 1, 1),
#  ('Japan', 'S700_2610', 'The USS Constitution Ship', 1, 1),
#  ('Japan', 'S700_2824', '1982 Camaro Z28', 1, 1),
#  ('Japan', 'S700_2834', 'ATA: B757-300', 1, 1),
#  ('Japan', 'S700_3167', 'F/A 18 Hornet 1/72', 1, 1),
#  ('Japan', 'S700_4002', 'American Airlines: MD-11S', 2, 2),
#  ('Japan', 'S72_1253', 'Boeing X-32A JSF', 1, 1),
#  ('New Zealand', 'S10_1678', '1969 Harley Davidson Ultimate Chopper', 2, 2),
#  ('New Zealand', 'S10_2016', '1996 Moto Guzzi 1100i', 2, 2),
#  ('New Zealand', 'S10_4698', '2003 Harley-Davidson Eagle Drag Bike', 2, 2),
#  ('New Zealand', 'S10_4757', '1972 Alfa Romeo GTA', 1, 1),
#  ('New Zealand', 'S12_1099', '1968 Ford Mustang', 1, 2),
#  ('New Zealand', 'S12_1108', '2001 Ferrari Enzo', 1, 1),
#  ('New Zealand', 'S12_2823', '2002 Suzuki XREO', 2, 2),
#  ('New Zealand', 'S12_3148', '1969 Corvair Monza', 2, 2),
#  ('New Zealand', 'S12_3380', '1968 Dodge Charger', 1, 2),
#  ('New Zealand', 'S12_3891', '1969 Ford Falcon', 1, 1),
#  ('New Zealand', 'S12_3990', '1970 Plymouth Hemi Cuda', 1, 2),
#  ('New Zealand', 'S12_4473', '1957 Chevy Pickup', 1, 1),
#  ('New Zealand', 'S12_4675', '1969 Dodge Charger', 1, 1),
#  ('New Zealand', 'S18_1342', '1937 Lincoln Berline', 2, 2),
#  ('New Zealand', 'S18_1367', '1936 Mercedes-Benz 500K Special Roadster', 2, 2),
#  ('New Zealand', 'S18_1662', '1980s Black Hawk Helicopter', 2, 2),
#  ('New Zealand', 'S18_1749', '1917 Grand Touring Sedan', 3, 3),
#  ('New Zealand', 'S18_1889', '1948 Porsche 356-A Roadster', 1, 1),
#  ('New Zealand', 'S18_2238', '1998 Chrysler Plymouth Prowler', 1, 1),
#  ('New Zealand', 'S18_2248', '1911 Ford Town Car', 3, 3),
#  ('New Zealand', 'S18_2319', '1964 Mercedes Tour Bus', 1, 1),
#  ('New Zealand', 'S18_2325', '1932 Model A Ford J-Coupe', 3, 3),
#  ('New Zealand', 'S18_2581', 'P-51-D Mustang', 1, 2),
#  ('New Zealand', 'S18_2625', '1936 Harley Davidson El Knucklehead', 2, 2),
#  ('New Zealand', 'S18_2795', '1928 Mercedes-Benz SSK', 2, 2),
#  ('New Zealand', 'S18_2949', '1913 Ford Model T Speedster', 1, 1),
#  ('New Zealand', 'S18_2957', '1934 Ford V8 Coupe', 1, 1),
#  ('New Zealand', 'S18_3029', '1999 Yamaha Speed Boat', 2, 2),
#  ('New Zealand', 'S18_3136', '18th Century Vintage Horse Carriage', 1, 1),
#  ('New Zealand', 'S18_3140', '1903 Ford Model A', 2, 2),
#  ('New Zealand', 'S18_3259', 'Collectable Wooden Train', 2, 2),
#  ('New Zealand', 'S18_3278', '1969 Dodge Super Bee', 2, 3),
#  ('New Zealand', 'S18_3320', '1917 Maxwell Touring Car', 2, 2),
#  ('New Zealand', 'S18_3482', '1976 Ford Gran Torino', 2, 2),
#  ('New Zealand', 'S18_3782', '1957 Vespa GS150', 2, 2),
#  ('New Zealand', 'S18_3856', '1941 Chevrolet Special Deluxe Cabriolet', 2, 2),
#  ('New Zealand', 'S18_4027', '1970 Triumph Spitfire', 1, 1),
#  ('New Zealand', 'S18_4409', '1932 Alfa Romeo 8C2300 Spider Sport', 3, 3),
#  ('New Zealand', 'S18_4522', '1904 Buick Runabout', 1, 1),
#  ('New Zealand', 'S18_4600', '1940s Ford truck', 1, 1),
#  ('New Zealand', 'S18_4668', '1939 Cadillac Limousine', 1, 1),
#  ('New Zealand', 'S18_4721', '1957 Corvette Convertible', 3, 3),
#  ('New Zealand', 'S18_4933', '1957 Ford Thunderbird', 2, 2),
#  ('New Zealand', 'S24_1046', '1970 Chevy Chevelle SS 454', 2, 2),
#  ('New Zealand', 'S24_1578', '1997 BMW R 1100 S', 2, 2),
#  ('New Zealand', 'S24_1628', '1966 Shelby Cobra 427 S/C', 1, 1),
#  ('New Zealand', 'S24_1785', '1928 British Royal Navy Airplane', 1, 2),
#  ('New Zealand', 'S24_1937', '1939 Chevrolet Deluxe Coupe', 3, 3),
#  ('New Zealand', 'S24_2000', '1960 BSA Gold Star DBD34', 2, 2),
#  ('New Zealand', 'S24_2011', '18th century schooner', 1, 1),
#  ('New Zealand', 'S24_2022', '1938 Cadillac V-16 Presidential Limousine', 3, 3),
#  ('New Zealand', 'S24_2300', '1962 Volkswagen Microbus', 1, 1),
#  ('New Zealand', 'S24_2360', '1982 Ducati 900 Monster', 2, 2),
#  ('New Zealand', 'S24_2766', '1949 Jaguar XK 120', 2, 2),
#  ('New Zealand', 'S24_2841', '1900s Vintage Bi-Plane', 2, 2),
#  ('New Zealand', 'S24_2887', '1952 Citroen-15CV', 2, 2),
#  ('New Zealand', 'S24_3151', '1912 Ford Model T Delivery Wagon', 1, 1),
#  ('New Zealand', 'S24_3191', '1969 Chevrolet Camaro Z28', 2, 2),
#  ('New Zealand', 'S24_3371', '1971 Alpine Renault 1600s', 1, 1),
#  ('New Zealand', 'S24_3420', '1937 Horch 930V Limousine', 1, 1),
#  ('New Zealand', 'S24_3432', '2002 Chevy Corvette', 2, 2),
#  ('New Zealand', 'S24_3816', '1940 Ford Delivery Sedan', 2, 2),
#  ('New Zealand', 'S24_3969', '1936 Mercedes Benz 500k Roadster', 3, 3),
#  ('New Zealand', 'S24_4048', '1992 Porsche Cayenne Turbo Silver', 1, 1),
#  ('New Zealand', 'S24_4258', '1936 Chrysler Airflow', 2, 2),
#  ('New Zealand', 'S24_4278', '1900s Vintage Tri-Plane', 1, 1),
#  ('New Zealand', 'S24_4620', '1961 Chevrolet Impala', 3, 3),
#  ('New Zealand', 'S32_1268', '1980ÔÇÖs GM Manhattan Express', 1, 1),
#  ('New Zealand', 'S32_1374', '1997 BMW F650 ST', 1, 2),
#  ('New Zealand', 'S32_2206', '1982 Ducati 996 R', 2, 2),
#  ('New Zealand', 'S32_3207', "1950's Chicago Surface Lines Streetcar", 1, 1),
#  ('New Zealand', 'S32_3522', '1996 Peterbilt 379 Stake Bed with Outrigger', 1, 1),
#  ('New Zealand', 'S32_4289', '1928 Ford Phaeton Deluxe', 1, 1),
#  ('New Zealand', 'S32_4485', '1974 Ducati 350 Mk3 Desmo', 2, 2),
#  ('New Zealand', 'S50_1341', '1930 Buick Marquette Phaeton', 1, 1),
#  ('New Zealand', 'S50_1514', '1962 City of Detroit Streetcar', 1, 1),
#  ('New Zealand', 'S50_4713', '2002 Yamaha YZR M1', 2, 2),
#  ('New Zealand', 'S700_1138', 'The Schooner Bluenose', 1, 1),
#  ('New Zealand', 'S700_1691', 'American Airlines: B767-300', 1, 1),
#  ('New Zealand', 'S700_1938', 'The Mayflower', 2, 2),
#  ('New Zealand', 'S700_2047', 'HMS Bounty', 1, 1),
#  ('New Zealand', 'S700_2610', 'The USS Constitution Ship', 1, 1),
#  ('New Zealand', 'S700_2824', '1982 Camaro Z28', 1, 1),
#  ('New Zealand', 'S700_2834', 'ATA: B757-300', 1, 1),
#  ('New Zealand', 'S700_3167', 'F/A 18 Hornet 1/72', 2, 2),
#  ('New Zealand', 'S700_3505', 'The Titanic', 1, 1),
#  ('New Zealand', 'S700_3962', 'The Queen Mary', 1, 1),
#  ('New Zealand', 'S72_1253', 'Boeing X-32A JSF', 1, 1),
#  ('New Zealand', 'S72_3212', 'Pont Yacht', 1, 1),
#  ('Norway', 'S10_1678', '1969 Harley Davidson Ultimate Chopper', 1, 1),
#  ('Norway', 'S10_1949', '1952 Alpine Renault 1300', 1, 1),
#  ('Norway', 'S10_4757', '1972 Alfa Romeo GTA', 1, 1),
#  ('Norway', 'S10_4962', '1962 LanciaA Delta 16V', 1, 1),
#  ('Norway', 'S12_1108', '2001 Ferrari Enzo', 1, 1),
#  ('Norway', 'S12_1666', '1958 Setra Bus', 1, 1),
#  ('Norway', 'S12_2823', '2002 Suzuki XREO', 1, 1),
#  ('Norway', 'S12_3891', '1969 Ford Falcon', 1, 1),
#  ('Norway', 'S18_1097', '1940 Ford Pickup Truck', 1, 1),
#  ('Norway', 'S18_2432', '1926 Ford Fire Engine', 1, 1),
#  ('Norway', 'S18_2949', '1913 Ford Model T Speedster', 1, 1),
#  ('Norway', 'S18_2957', '1934 Ford V8 Coupe', 1, 1),
#  ('Norway', 'S18_3136', '18th Century Vintage Horse Carriage', 1, 1),
#  ('Norway', 'S18_3140', '1903 Ford Model A', 1, 1),
#  ('Norway', 'S18_3320', '1917 Maxwell Touring Car', 1, 1),
#  ('Norway', 'S18_4600', '1940s Ford truck', 1, 1),
#  ('Norway', 'S18_4668', '1939 Cadillac Limousine', 1, 1),
#  ('Norway', 'S24_1578', '1997 BMW R 1100 S', 1, 1),
#  ('Norway', 'S24_2000', '1960 BSA Gold Star DBD34', 1, 1),
#  ('Norway', 'S24_2300', '1962 Volkswagen Microbus', 1, 1),
#  ('Norway', 'S24_2360', '1982 Ducati 900 Monster', 1, 1),
#  ('Norway', 'S24_4048', '1992 Porsche Cayenne Turbo Silver', 1, 1),
#  ('Norway', 'S24_4258', '1936 Chrysler Airflow', 1, 1),
#  ('Norway', 'S32_1268', '1980ÔÇÖs GM Manhattan Express', 1, 1),
#  ('Norway', 'S32_2509', '1954 Greyhound Scenicruiser', 1, 1),
#  ('Norway', 'S32_3207', "1950's Chicago Surface Lines Streetcar", 1, 1),
#  ('Norway', 'S32_3522', '1996 Peterbilt 379 Stake Bed with Outrigger', 1, 1),
#  ('Norway', 'S32_4485', '1974 Ducati 350 Mk3 Desmo', 1, 1),
#  ('Norway', 'S50_1392', 'Diamond T620 Semi-Skirted Tanker', 1, 1),
#  ('Norway', 'S50_1514', '1962 City of Detroit Streetcar', 1, 1),
#  ('Norway', 'S50_4713', '2002 Yamaha YZR M1', 1, 1),
#  ('Norway', 'S700_2824', '1982 Camaro Z28', 1, 1),
#  ('Norway  ', 'S10_1678', '1969 Harley Davidson Ultimate Chopper', 1, 1),
#  ('Norway  ', 'S10_2016', '1996 Moto Guzzi 1100i', 1, 1),
#  ('Norway  ', 'S10_4698', '2003 Harley-Davidson Eagle Drag Bike', 1, 1),
#  ('Norway  ', 'S12_1099', '1968 Ford Mustang', 1, 1),
#  ('Norway  ', 'S12_3380', '1968 Dodge Charger', 1, 1),
#  ('Norway  ', 'S12_3990', '1970 Plymouth Hemi Cuda', 1, 1),
#  ('Norway  ', 'S12_4675', '1969 Dodge Charger', 1, 1),
#  ('Norway  ', 'S18_1129', '1993 Mazda RX-7', 2, 2),
#  ('Norway  ', 'S18_1342', '1937 Lincoln Berline', 1, 1),
#  ('Norway  ', 'S18_1367', '1936 Mercedes-Benz 500K Special Roadster', 1, 1),
#  ('Norway  ', 'S18_1589', '1965 Aston Martin DB5', 2, 2),
#  ('Norway  ', 'S18_1662', '1980s Black Hawk Helicopter', 1, 1),
#  ('Norway  ', 'S18_1889', '1948 Porsche 356-A Roadster', 1, 1),
#  ('Norway  ', 'S18_1984', '1995 Honda Civic', 2, 2),
#  ('Norway  ', 'S18_2581', 'P-51-D Mustang', 1, 1),
#  ('Norway  ', 'S18_2625', '1936 Harley Davidson El Knucklehead', 1, 1),
#  ('Norway  ', 'S18_2795', '1928 Mercedes-Benz SSK', 1, 1),
#  ('Norway  ', 'S18_2870', '1999 Indy 500 Monte Carlo SS', 2, 2),
#  ('Norway  ', 'S18_3232', '1992 Ferrari 360 Spider red', 2, 2),
#  ('Norway  ', 'S18_3278', '1969 Dodge Super Bee', 1, 1),
#  ('Norway  ', 'S18_3482', '1976 Ford Gran Torino', 1, 1),
#  ('Norway  ', 'S18_3685', '1948 Porsche Type 356 Roadster', 2, 2),
#  ('Norway  ', 'S24_1046', '1970 Chevy Chevelle SS 454', 1, 1),
#  ('Norway  ', 'S24_1578', '1997 BMW R 1100 S', 1, 1),
#  ('Norway  ', 'S24_1628', '1966 Shelby Cobra 427 S/C', 2, 2),
#  ('Norway  ', 'S24_1785', '1928 British Royal Navy Airplane', 1, 1),
#  ('Norway  ', 'S24_2000', '1960 BSA Gold Star DBD34', 1, 1),
#  ('Norway  ', 'S24_2022', '1938 Cadillac V-16 Presidential Limousine', 1, 1),
#  ('Norway  ', 'S24_2841', '1900s Vintage Bi-Plane', 1, 1),
#  ('Norway  ', 'S24_2972', '1982 Lamborghini Diablo', 2, 2),
#  ('Norway  ', 'S24_3371', '1971 Alpine Renault 1600s', 1, 1),
#  ('Norway  ', 'S24_3420', '1937 Horch 930V Limousine', 1, 1),
#  ('Norway  ', 'S24_3432', '2002 Chevy Corvette', 1, 1),
#  ('Norway  ', 'S24_3856', '1956 Porsche 356A Coupe', 2, 2),
#  ('Norway  ', 'S24_3949', 'Corsair F4U ( Bird Cage)', 1, 1),
#  ('Norway  ', 'S24_4278', '1900s Vintage Tri-Plane', 1, 1),
#  ('Norway  ', 'S32_1374', '1997 BMW F650 ST', 1, 1),
#  ('Norway  ', 'S32_4289', '1928 Ford Phaeton Deluxe', 1, 1),
#  ('Norway  ', 'S50_1341', '1930 Buick Marquette Phaeton', 1, 1),
#  ('Norway  ', 'S700_1691', 'American Airlines: B767-300', 1, 1),
#  ('Norway  ', 'S700_2466', 'America West Airlines B757-200', 1, 1),
#  ('Norway  ', 'S700_2834', 'ATA: B757-300', 1, 1),
#  ('Norway  ', 'S700_3167', 'F/A 18 Hornet 1/72', 1, 1),
#  ('Norway  ', 'S700_4002', 'American Airlines: MD-11S', 1, 1),
#  ('Philippines', 'S12_1099', '1968 Ford Mustang', 1, 1),
#  ('Philippines', 'S12_3380', '1968 Dodge Charger', 1, 1),
#  ('Philippines', 'S12_3990', '1970 Plymouth Hemi Cuda', 1, 1),
#  ('Philippines', 'S12_4675', '1969 Dodge Charger', 1, 1),
#  ('Philippines', 'S18_1662', '1980s Black Hawk Helicopter', 1, 1),
#  ('Philippines', 'S18_1889', '1948 Porsche 356-A Roadster', 1, 1),
#  ('Philippines', 'S18_3278', '1969 Dodge Super Bee', 1, 1),
#  ('Philippines', 'S18_3482', '1976 Ford Gran Torino', 1, 2),
#  ('Philippines', 'S18_3782', '1957 Vespa GS150', 1, 2),
#  ('Philippines', 'S18_4721', '1957 Corvette Convertible', 1, 2),
#  ('Philippines', 'S24_2360', '1982 Ducati 900 Monster', 1, 2),
#  ('Philippines', 'S24_2841', '1900s Vintage Bi-Plane', 1, 1),
#  ('Philippines', 'S24_3371', '1971 Alpine Renault 1600s', 1, 1),
#  ('Philippines', 'S24_3420', '1937 Horch 930V Limousine', 1, 1),
#  ('Philippines', 'S24_3856', '1956 Porsche 356A Coupe', 1, 1),
#  ('Philippines', 'S24_3949', 'Corsair F4U ( Bird Cage)', 1, 1),
#  ('Philippines', 'S24_4620', '1961 Chevrolet Impala', 1, 1),
#  ('Philippines', 'S32_2206', '1982 Ducati 996 R', 1, 1),
#  ('Philippines', 'S32_4485', '1974 Ducati 350 Mk3 Desmo', 1, 1),
#  ('Philippines', 'S50_4713', '2002 Yamaha YZR M1', 1, 1),
#  ('Philippines', 'S700_2466', 'America West Airlines B757-200', 1, 1),
#  ('Philippines', 'S700_4002', 'American Airlines: MD-11S', 1, 1),
#  ('Singapore', 'S10_1949', '1952 Alpine Renault 1300', 1, 1),
#  ('Singapore', 'S10_4962', '1962 LanciaA Delta 16V', 2, 3),
#  ('Singapore', 'S12_1108', '2001 Ferrari Enzo', 1, 2),
#  ('Singapore', 'S12_1666', '1958 Setra Bus', 1, 1),
#  ('Singapore', 'S12_3148', '1969 Corvair Monza', 1, 2),
#  ('Singapore', 'S12_3891', '1969 Ford Falcon', 1, 2),
#  ('Singapore', 'S12_4473', '1957 Chevy Pickup', 2, 2),
#  ('Singapore', 'S12_4675', '1969 Dodge Charger', 1, 1),
#  ('Singapore', 'S18_1097', '1940 Ford Pickup Truck', 1, 1),
#  ('Singapore', 'S18_1589', '1965 Aston Martin DB5', 1, 1),
#  ('Singapore', 'S18_1749', '1917 Grand Touring Sedan', 1, 1),
#  ('Singapore', 'S18_2238', '1998 Chrysler Plymouth Prowler', 2, 2),
#  ('Singapore', 'S18_2248', '1911 Ford Town Car', 1, 1),
#  ('Singapore', 'S18_2319', '1964 Mercedes Tour Bus', 2, 2),
#  ('Singapore', 'S18_2325', '1932 Model A Ford J-Coupe', 1, 2),
#  ('Singapore', 'S18_2432', '1926 Ford Fire Engine', 2, 3),
#  ('Singapore', 'S18_2949', '1913 Ford Model T Speedster', 1, 1),
#  ('Singapore', 'S18_2957', '1934 Ford V8 Coupe', 1, 1),
#  ('Singapore', 'S18_3136', '18th Century Vintage Horse Carriage', 1, 1),
#  ('Singapore', 'S18_3140', '1903 Ford Model A', 1, 1),
#  ('Singapore', 'S18_3232', '1992 Ferrari 360 Spider red', 2, 2),
#  ('Singapore', 'S18_3259', 'Collectable Wooden Train', 1, 2),
#  ('Singapore', 'S18_4027', '1970 Triumph Spitfire', 1, 2),
#  ('Singapore', 'S18_4409', '1932 Alfa Romeo 8C2300 Spider Sport', 1, 1),
#  ('Singapore', 'S18_4522', '1904 Buick Runabout', 1, 1),
#  ('Singapore', 'S18_4600', '1940s Ford truck', 2, 3),
#  ('Singapore', 'S18_4668', '1939 Cadillac Limousine', 1, 1),
#  ('Singapore', 'S18_4933', '1957 Ford Thunderbird', 1, 1),
#  ('Singapore', 'S24_1046', '1970 Chevy Chevelle SS 454', 1, 1),
#  ('Singapore', 'S24_1444', '1970 Dodge Coronet', 2, 2),
#  ('Singapore', 'S24_1628', '1966 Shelby Cobra 427 S/C', 1, 1),
#  ('Singapore', 'S24_1937', '1939 Chevrolet Deluxe Coupe', 1, 2),
#  ('Singapore', 'S24_2011', '18th century schooner', 1, 1),
#  ('Singapore', 'S24_2300', '1962 Volkswagen Microbus', 2, 3),
#  ('Singapore', 'S24_2766', '1949 Jaguar XK 120', 1, 1),
#  ('Singapore', 'S24_2840', '1958 Chevy Corvette Limited Edition', 2, 2),
#  ('Singapore', 'S24_2887', '1952 Citroen-15CV', 1, 1),
#  ('Singapore', 'S24_3191', '1969 Chevrolet Camaro Z28', 1, 1),
#  ('Singapore', 'S24_3432', '2002 Chevy Corvette', 1, 1),
#  ('Singapore', 'S24_3969', '1936 Mercedes Benz 500k Roadster', 1, 1),
#  ('Singapore', 'S24_4048', '1992 Porsche Cayenne Turbo Silver', 1, 1),
#  ('Singapore', 'S32_1268', '1980ÔÇÖs GM Manhattan Express', 1, 2),
#  ('Singapore', 'S32_1374', '1997 BMW F650 ST', 1, 1),
#  ('Singapore', 'S32_2509', '1954 Greyhound Scenicruiser', 2, 2),
#  ('Singapore', 'S32_3207', "1950's Chicago Surface Lines Streetcar", 1, 1),
#  ('Singapore', 'S32_3522', '1996 Peterbilt 379 Stake Bed with Outrigger', 2, 2),
#  ('Singapore', 'S50_1392', 'Diamond T620 Semi-Skirted Tanker', 2, 2),
#  ('Singapore', 'S50_1514', '1962 City of Detroit Streetcar', 1, 2),
#  ('Singapore', 'S700_1938', 'The Mayflower', 1, 1),
#  ('Singapore', 'S700_2824', '1982 Camaro Z28', 2, 2),
#  ('Singapore', 'S700_3962', 'The Queen Mary', 1, 1),
#  ('Singapore', 'S72_3212', 'Pont Yacht', 1, 1),
#  ('Spain', 'S10_1678', '1969 Harley Davidson Ultimate Chopper', 1, 1),
#  ('Spain', 'S10_1949', '1952 Alpine Renault 1300', 2, 2),
#  ('Spain', 'S10_2016', '1996 Moto Guzzi 1100i', 1, 1),
#  ('Spain', 'S10_4698', '2003 Harley-Davidson Eagle Drag Bike', 1, 1),
#  ('Spain', 'S10_4757', '1972 Alfa Romeo GTA', 2, 2),
#  ('Spain', 'S10_4962', '1962 LanciaA Delta 16V', 1, 1),
#  ('Spain', 'S12_1099', '1968 Ford Mustang', 1, 1),
#  ('Spain', 'S12_1108', '2001 Ferrari Enzo', 3, 3),
#  ('Spain', 'S12_1666', '1958 Setra Bus', 2, 2),
#  ('Spain', 'S12_2823', '2002 Suzuki XREO', 1, 1),
#  ('Spain', 'S12_3148', '1969 Corvair Monza', 2, 4),
#  ('Spain', 'S12_3380', '1968 Dodge Charger', 1, 2),
#  ('Spain', 'S12_3891', '1969 Ford Falcon', 2, 2),
#  ('Spain', 'S12_3990', '1970 Plymouth Hemi Cuda', 1, 1),
#  ('Spain', 'S12_4473', '1957 Chevy Pickup', 2, 5),
#  ('Spain', 'S12_4675', '1969 Dodge Charger', 1, 2),
#  ('Spain', 'S18_1097', '1940 Ford Pickup Truck', 2, 2),
#  ('Spain', 'S18_1129', '1993 Mazda RX-7', 1, 1),
#  ('Spain', 'S18_1342', '1937 Lincoln Berline', 1, 3),
#  ('Spain', 'S18_1367', '1936 Mercedes-Benz 500K Special Roadster', 2, 3),
#  ('Spain', 'S18_1589', '1965 Aston Martin DB5', 1, 3),
#  ('Spain', 'S18_1662', '1980s Black Hawk Helicopter', 1, 2),
#  ('Spain', 'S18_1749', '1917 Grand Touring Sedan', 2, 2),
#  ('Spain', 'S18_1889', '1948 Porsche 356-A Roadster', 1, 2),
#  ('Spain', 'S18_1984', '1995 Honda Civic', 1, 1),
#  ('Spain', 'S18_2238', '1998 Chrysler Plymouth Prowler', 2, 5),
#  ('Spain', 'S18_2248', '1911 Ford Town Car', 3, 3),
#  ('Spain', 'S18_2319', '1964 Mercedes Tour Bus', 2, 6),
#  ('Spain', 'S18_2325', '1932 Model A Ford J-Coupe', 2, 2),
#  ('Spain', 'S18_2432', '1926 Ford Fire Engine', 3, 4),
#  ('Spain', 'S18_2581', 'P-51-D Mustang', 1, 2),
#  ('Spain', 'S18_2625', '1936 Harley Davidson El Knucklehead', 1, 1),
#  ('Spain', 'S18_2795', '1928 Mercedes-Benz SSK', 2, 4),
#  ('Spain', 'S18_2870', '1999 Indy 500 Monte Carlo SS', 1, 3),
#  ('Spain', 'S18_2949', '1913 Ford Model T Speedster', 2, 2),
#  ('Spain', 'S18_2957', '1934 Ford V8 Coupe', 2, 2),
#  ('Spain', 'S18_3029', '1999 Yamaha Speed Boat', 2, 4),
#  ('Spain', 'S18_3136', '18th Century Vintage Horse Carriage', 2, 2),
#  ('Spain', 'S18_3140', '1903 Ford Model A', 2, 5),
#  ('Spain', 'S18_3232', '1992 Ferrari 360 Spider red', 2, 9),
#  ('Spain', 'S18_3259', 'Collectable Wooden Train', 2, 5),
#  ('Spain', 'S18_3278', '1969 Dodge Super Bee', 1, 2),
#  ('Spain', 'S18_3320', '1917 Maxwell Touring Car', 2, 2),
#  ('Spain', 'S18_3482', '1976 Ford Gran Torino', 1, 3),
#  ('Spain', 'S18_3685', '1948 Porsche Type 356 Roadster', 1, 3),
#  ('Spain', 'S18_3782', '1957 Vespa GS150', 1, 2),
#  ('Spain', 'S18_3856', '1941 Chevrolet Special Deluxe Cabriolet', 2, 3),
#  ('Spain', 'S18_4027', '1970 Triumph Spitfire', 1, 4),
#  ('Spain', 'S18_4409', '1932 Alfa Romeo 8C2300 Spider Sport', 1, 2),
#  ('Spain', 'S18_4522', '1904 Buick Runabout', 3, 6),
#  ('Spain', 'S18_4600', '1940s Ford truck', 1, 1),
#  ('Spain', 'S18_4668', '1939 Cadillac Limousine', 2, 4),
#  ('Spain', 'S18_4721', '1957 Corvette Convertible', 1, 2),
#  ('Spain', 'S18_4933', '1957 Ford Thunderbird', 1, 3),
#  ('Spain', 'S24_1046', '1970 Chevy Chevelle SS 454', 1, 4),
#  ('Spain', 'S24_1444', '1970 Dodge Coronet', 2, 7),
#  ('Spain', 'S24_1578', '1997 BMW R 1100 S', 1, 1),
#  ('Spain', 'S24_1628', '1966 Shelby Cobra 427 S/C', 1, 3),
#  ('Spain', 'S24_1785', '1928 British Royal Navy Airplane', 1, 3),
#  ('Spain', 'S24_1937', '1939 Chevrolet Deluxe Coupe', 2, 3),
#  ('Spain', 'S24_2000', '1960 BSA Gold Star DBD34', 1, 1),
#  ('Spain', 'S24_2011', '18th century schooner', 3, 4),
#  ('Spain', 'S24_2022', '1938 Cadillac V-16 Presidential Limousine', 2, 4),
#  ('Spain', 'S24_2300', '1962 Volkswagen Microbus', 3, 6),
#  ('Spain', 'S24_2360', '1982 Ducati 900 Monster', 1, 2),
#  ('Spain', 'S24_2766', '1949 Jaguar XK 120', 1, 4),
#  ('Spain', 'S24_2840', '1958 Chevy Corvette Limited Edition', 2, 7),
#  ('Spain', 'S24_2841', '1900s Vintage Bi-Plane', 1, 2),
#  ('Spain', 'S24_2887', '1952 Citroen-15CV', 1, 3),
#  ('Spain', 'S24_2972', '1982 Lamborghini Diablo', 1, 4),
#  ('Spain', 'S24_3151', '1912 Ford Model T Delivery Wagon', 3, 3),
#  ('Spain', 'S24_3191', '1969 Chevrolet Camaro Z28', 1, 4),
#  ('Spain', 'S24_3371', '1971 Alpine Renault 1600s', 1, 3),
#  ('Spain', 'S24_3420', '1937 Horch 930V Limousine', 1, 2),
#  ('Spain', 'S24_3432', '2002 Chevy Corvette', 1, 4),
#  ('Spain', 'S24_3816', '1940 Ford Delivery Sedan', 2, 3),
#  ('Spain', 'S24_3856', '1956 Porsche 356A Coupe', 1, 4),
#  ('Spain', 'S24_3949', 'Corsair F4U ( Bird Cage)', 1, 2),
#  ('Spain', 'S24_3969', '1936 Mercedes Benz 500k Roadster', 3, 3),
#  ('Spain', 'S24_4048', '1992 Porsche Cayenne Turbo Silver', 2, 6),
#  ('Spain', 'S24_4258', '1936 Chrysler Airflow', 2, 4),
#  ('Spain', 'S24_4278', '1900s Vintage Tri-Plane', 2, 3),
#  ('Spain', 'S24_4620', '1961 Chevrolet Impala', 1, 2),
#  ('Spain', 'S32_1268', '1980ÔÇÖs GM Manhattan Express', 3, 4),
#  ('Spain', 'S32_1374', '1997 BMW F650 ST', 2, 2),
#  ('Spain', 'S32_2206', '1982 Ducati 996 R', 1, 3),
#  ('Spain', 'S32_2509', '1954 Greyhound Scenicruiser', 2, 6),
#  ('Spain', 'S32_3207', "1950's Chicago Surface Lines Streetcar", 2, 5),
#  ('Spain', 'S32_3522', '1996 Peterbilt 379 Stake Bed with Outrigger', 2, 4),
#  ('Spain', 'S32_4289', '1928 Ford Phaeton Deluxe', 2, 3),
#  ('Spain', 'S32_4485', '1974 Ducati 350 Mk3 Desmo', 1, 2),
#  ('Spain', 'S50_1341', '1930 Buick Marquette Phaeton', 2, 4),
#  ('Spain', 'S50_1392', 'Diamond T620 Semi-Skirted Tanker', 2, 6),
#  ('Spain', 'S50_1514', '1962 City of Detroit Streetcar', 1, 4),
#  ('Spain', 'S50_4713', '2002 Yamaha YZR M1', 1, 1),
#  ('Spain', 'S700_1138', 'The Schooner Bluenose', 3, 4),
#  ('Spain', 'S700_1691', 'American Airlines: B767-300', 2, 4),
#  ('Spain', 'S700_1938', 'The Mayflower', 2, 4),
#  ('Spain', 'S700_2047', 'HMS Bounty', 2, 3),
#  ('Spain', 'S700_2466', 'America West Airlines B757-200', 2, 3),
#  ('Spain', 'S700_2610', 'The USS Constitution Ship', 3, 4),
#  ('Spain', 'S700_2824', '1982 Camaro Z28', 2, 4),
#  ('Spain', 'S700_2834', 'ATA: B757-300', 2, 2),
#  ('Spain', 'S700_3167', 'F/A 18 Hornet 1/72', 1, 2),
#  ('Spain', 'S700_3505', 'The Titanic', 3, 6),
#  ('Spain', 'S700_3962', 'The Queen Mary', 3, 5),
#  ('Spain', 'S700_4002', 'American Airlines: MD-11S', 1, 2),
#  ('Spain', 'S72_1253', 'Boeing X-32A JSF', 2, 3),
#  ('Spain', 'S72_3212', 'Pont Yacht', 3, 5),
#  ('Sweden', 'S10_1949', '1952 Alpine Renault 1300', 2, 2),
#  ('Sweden', 'S10_4757', '1972 Alfa Romeo GTA', 1, 1),
#  ('Sweden', 'S10_4962', '1962 LanciaA Delta 16V', 2, 2),
#  ('Sweden', 'S12_1099', '1968 Ford Mustang', 2, 2),
#  ('Sweden', 'S12_1666', '1958 Setra Bus', 1, 1),
#  ('Sweden', 'S12_3380', '1968 Dodge Charger', 2, 2),
#  ('Sweden', 'S12_3990', '1970 Plymouth Hemi Cuda', 2, 2),
#  ('Sweden', 'S12_4675', '1969 Dodge Charger', 1, 1),
#  ('Sweden', 'S18_1097', '1940 Ford Pickup Truck', 1, 1),
#  ('Sweden', 'S18_1662', '1980s Black Hawk Helicopter', 1, 1),
#  ('Sweden', 'S18_1889', '1948 Porsche 356-A Roadster', 1, 1),
#  ('Sweden', 'S18_2319', '1964 Mercedes Tour Bus', 1, 1),
#  ('Sweden', 'S18_2432', '1926 Ford Fire Engine', 2, 2),
#  ('Sweden', 'S18_2625', '1936 Harley Davidson El Knucklehead', 1, 1),
#  ('Sweden', 'S18_2949', '1913 Ford Model T Speedster', 2, 2),
#  ('Sweden', 'S18_2957', '1934 Ford V8 Coupe', 1, 1),
#  ('Sweden', 'S18_3029', '1999 Yamaha Speed Boat', 1, 1),
#  ('Sweden', 'S18_3136', '18th Century Vintage Horse Carriage', 1, 1),
#  ('Sweden', 'S18_3232', '1992 Ferrari 360 Spider red', 1, 1),
#  ('Sweden', 'S18_3259', 'Collectable Wooden Train', 1, 1),
#  ('Sweden', 'S18_3482', '1976 Ford Gran Torino', 1, 1),
#  ('Sweden', 'S18_3856', '1941 Chevrolet Special Deluxe Cabriolet', 1, 1),
#  ('Sweden', 'S18_4522', '1904 Buick Runabout', 1, 1),
#  ('Sweden', 'S18_4600', '1940s Ford truck', 2, 2),
#  ('Sweden', 'S18_4668', '1939 Cadillac Limousine', 1, 1),
#  ('Sweden', 'S24_1578', '1997 BMW R 1100 S', 1, 1),
#  ('Sweden', 'S24_2000', '1960 BSA Gold Star DBD34', 1, 1),
#  ('Sweden', 'S24_2011', '18th century schooner', 2, 2),
#  ('Sweden', 'S24_2300', '1962 Volkswagen Microbus', 2, 2),
#  ('Sweden', 'S24_2841', '1900s Vintage Bi-Plane', 1, 1),
#  ('Sweden', 'S24_3151', '1912 Ford Model T Delivery Wagon', 2, 2),
#  ('Sweden', 'S24_3371', '1971 Alpine Renault 1600s', 1, 1),
#  ('Sweden', 'S24_3420', '1937 Horch 930V Limousine', 1, 1),
#  ('Sweden', 'S24_3816', '1940 Ford Delivery Sedan', 2, 2),
#  ('Sweden', 'S32_1268', '1980ÔÇÖs GM Manhattan Express', 1, 1),
#  ('Sweden', 'S32_3522', '1996 Peterbilt 379 Stake Bed with Outrigger', 1, 1),
#  ('Sweden', 'S700_1138', 'The Schooner Bluenose', 2, 2),
#  ('Sweden', 'S700_2047', 'HMS Bounty', 1, 1),
#  ('Sweden', 'S700_2610', 'The USS Constitution Ship', 1, 1),
#  ('Sweden', 'S700_2824', '1982 Camaro Z28', 1, 1),
#  ...]
